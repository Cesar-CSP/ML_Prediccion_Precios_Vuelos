# %% [markdown]
# ¿Sería mejor diferenciar los vuelos para el modelo?
# Si quieres un modelo que prediga precios reales → NO
#
# No necesitas diferenciar:
#
# - “1-stop via Hyderabad”
# - “1-stop via Kolkata”
#
# Porque:
#
# - No afecta al precio
# - No aporta información útil
# - Añade ruido
# - Aumenta la dimensionalidad
# - Empeora el modelo
#
# Las aerolíneas no fijan precios según la ciudad de escala.
# Fijan precios según:
#
# - número de escalas
# - duración
# - demanda
# - antelación
# - competencia
# - franja horaria

# %% [markdown]
# 1. ¿Por qué fijar una fecha artificial NO daña el proyecto?
# Porque en el webscraping no existía la fecha real de consulta, y sin esa fecha:
#
# no puedes calcular la anticipación
#
# no puedes modelar la dinámica temporal
#
# no puedes explicar por qué un vuelo vale 50€ hoy y 200€ mañana
#
# el modelo no aprende nada útil
#
# La anticipación es la variable más importante en pricing aéreo.
# Sin ella, el modelo sería ciego.
#
# Por eso fijar una fecha artificial es la única forma correcta de reconstruir esa variable.
#
# 2. ¿Es suficiente para un proyecto bueno?
# - Sí, totalmente suficiente.
# - Es una práctica habitual en proyectos reales.
# - Es defendible técnicamente.
# - Es coherente con el plan de negocio.
#
# De hecho, en consultoría y data science se hace constantemente cuando:
#
# - falta la fecha de scraping
# - falta la fecha de compra
# - falta la fecha de registro
# - los datos vienen de APIs sin timestamp
# - Lo importante no es la fecha exacta, sino la consistencia.
#
# 3. ¿Por qué el 11 de febrero es válido?
#
# Porque:
#
# - es una fecha fija
#
# - es anterior a los vuelos del dataset
#
# - permite calcular la anticipación
#
# - no introduce sesgos
#
# - no afecta a la comparación entre aerolíneas
#
# - Si hubieras elegido el 10, el 12 o el 20, el modelo habría funcionado igual.
# - Lo importante es que sea una fecha única y coherente.

# %% [markdown]
# ⭐ 1. ¿Por qué dos filas se vuelven iguales después de las transformaciones?
# Porque cuando haces:
#
# limpieza
#
# conversión de fechas
#
# extracción de variables (mes, día, antelación…)
#
# codificación de aerolínea, origen, destino
#
# eliminación de columnas irrelevantes
#
# …te quedas solo con las variables que realmente explican el precio.
#
# Si dos vuelos tienen:
#
# misma aerolínea
#
# mismo origen
#
# mismo destino
#
# misma duración
#
# misma clase
#
# misma fecha de vuelo
#
# misma antelación
#
# mismas escalas
#
# Entonces son el mismo vuelo desde el punto de vista del modelo, aunque tengan distinto número de vuelo.
#
# ⭐ 2. ¿Por qué flight es lo único que los diferencia?
# Porque flight es un identificador, no una característica del vuelo.

# %%
import matplotlib.pyplot as plt
import joblib
import numpy as np
import optuna
import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate, cross_val_score
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer, OneHotEncoder, OrdinalEncoder, StandardScaler

from scipy import stats

import bootcampviztools as bt

pd.options.mode.copy_on_write = True

# %% [markdown]
# Este Dataset no lo pondremos en el archivo defintivo:

# %%
df_limpio = pd.read_csv("../data/Clean_Dataset.csv")
df_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        300153 non-null  int64
#  1   airline           300153 non-null  object
#  2   flight            300153 non-null  object
#  3   source_city       300153 non-null  object
#  4   departure_time    300153 non-null  object
#  5   stops             300153 non-null  object
#  6   arrival_time      300153 non-null  object
#  7   destination_city  300153 non-null  object
#  8   class             300153 non-null  object
#  9   duration          300153 non-null  float64
#  10  days_left         300153 non-null  int64
#  11  price             300153 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 27.5+ MB

# %%
df_limpio.head(30)
# Out:
#     Unnamed: 0    airline   flight source_city departure_time stops  \
# 0            0   SpiceJet  SG-8709       Delhi        Evening  zero
# 1            1   SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2            2    AirAsia   I5-764       Delhi  Early_Morning  zero
# 3            3    Vistara   UK-995       Delhi        Morning  zero
# 4            4    Vistara   UK-963       Delhi        Morning  zero
# 5            5    Vistara   UK-945       Delhi        Morning  zero
# 6            6    Vistara   UK-927       Delhi        Morning  zero
# 7            7    Vistara   UK-951       Delhi      Afternoon  zero
# 8            8   GO_FIRST   G8-334       Delhi  Early_Morning  zero
# 9            9   GO_FIRST   G8-336       Delhi      Afternoon  zero
# 10          10   GO_FIRST   G8-392       Delhi      Afternoon  zero
# 11          11   GO_FIRST   G8-338       Delhi        Morning  zero
# 12          12     Indigo  6E-5001       Delhi  Early_Morning  zero
# 13          13     Indigo  6E-6202       Delhi        Morning  zero
# 14          14     Indigo   6E-549       Delhi      Afternoon  zero
# 15          15     Indigo  6E-6278       Delhi        Morning  zero
# 16          16  Air_India   AI-887       Delhi  Early_Morning  zero
# 17          17  Air_India   AI-665       Delhi  Early_Morning  zero
# 18          18    AirAsia   I5-747       Delhi        Evening   one
# 19          19    AirAsia   I5-747       Delhi        Evening   one
# 20          20   GO_FIRST   G8-266       Delhi  Early_Morning   one
# 21          21   GO_FIRST   G8-101       Delhi  Early_Morning   one
# 22          22   GO_FIRST   G8-103       Delhi        Evening   one
# 23          23  Air_India   AI-441       Delhi        Evening   one
# 24          24     Indigo  6E-5328       Delhi        Morning  zero
# 25          25    Vistara   UK-933       Delhi      Afternoon  zero
# 26          26     Indigo  6E-2046       Delhi        Evening  zero
# 27          27    AirAsia   I5-744       Delhi        Morning   one
# 28          28   SpiceJet  SG-8169       Delhi        Evening  zero
# 29          29     Indigo  6E-5041       Delhi        Evening  zero
#
#      arrival_time destination_city    class  duration  days_left  price
# 0           Night           Mumbai  Economy      2.17          1   5953
# 1         Morning           Mumbai  Economy      2.33          1   5953
# 2   Early_Morning           Mumbai  Economy      2.17          1   5956
# 3       Afternoon           Mumbai  Economy      2.25          1   5955
# 4         Morning           Mumbai  Economy      2.33          1   5955
# 5       Afternoon           Mumbai  Economy      2.33          1   5955
# 6         Morning           Mumbai  Economy      2.08          1   6060
# 7         Evening           Mumbai  Economy      2.17          1   6060
# 8         Morning           Mumbai  Economy      2.17          1   5954
# 9         Evening           Mumbai  Economy      2.25          1   5954
# 10        Evening           Mumbai  Economy      2.25          1   5954
# 11      Afternoon           Mumbai  Economy      2.33          1   5954
# 12        Morning           Mumbai  Economy      2.17          1   5955
# 13      Afternoon           Mumbai  Economy      2.17          1   5955
# 14        Evening           Mumbai  Economy      2.25          1   5955
# 15        Morning           Mumbai  Economy      2.33          1   5955
# 16        Morning           Mumbai  Economy      2.08          1   5955
# 17        Morning           Mumbai  Economy      2.17          1   5955
# 18  Early_Morning           Mumbai  Economy     12.25          1   5949
# 19        Morning           Mumbai  Economy     16.33          1   5949
# 20        Evening           Mumbai  Economy     11.75          1   5954
# 21          Night           Mumbai  Economy     14.50          1   5954
# 22        Morning           Mumbai  Economy     15.67          1   5954
# 23          Night           Mumbai  Economy      3.75          1   5955
# 24        Morning           Mumbai  Economy      2.50          1   6165
# 25        Evening           Mumbai  Economy      2.17          1   6690
# 26        Evening           Mumbai  Economy      2.17          1   6585
# 27      Afternoon           Mumbai  Economy      5.83          1   8869
# 28          Night           Mumbai  Economy      2.33          1  10260
# 29          Night           Mumbai  Economy      2.17          1  10470

# %%
df_limpio.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_limpio[df_limpio.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, airline, flight, source_city, departure_time, stops, arrival_time, destination_city, class, duration, days_left, price]
# Index: []

# %% [markdown]
# **ECONOMY**

# %%
df_economy = pd.read_csv("../data/economy.csv")
df_economy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206774 entries, 0 to 206773
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        206774 non-null  object
#  1   airline     206774 non-null  object
#  2   ch_code     206774 non-null  object
#  3   num_code    206774 non-null  int64
#  4   dep_time    206774 non-null  object
#  5   from        206774 non-null  object
#  6   time_taken  206774 non-null  object
#  7   stop        206774 non-null  object
#  8   arr_time    206774 non-null  object
#  9   to          206774 non-null  object
#  10  price       206774 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 17.4+ MB

# %%
df_economy.head(10)
# Out:
#          date   airline ch_code  num_code dep_time   from time_taken  \
# 0  11-02-2022  SpiceJet      SG      8709    18:55  Delhi    02h 10m
# 1  11-02-2022  SpiceJet      SG      8157    06:20  Delhi    02h 20m
# 2  11-02-2022   AirAsia      I5       764    04:25  Delhi    02h 10m
# 3  11-02-2022   Vistara      UK       995    10:20  Delhi    02h 15m
# 4  11-02-2022   Vistara      UK       963    08:50  Delhi    02h 20m
# 5  11-02-2022   Vistara      UK       945    11:40  Delhi    02h 20m
# 6  11-02-2022   Vistara      UK       927    09:30  Delhi    02h 05m
# 7  11-02-2022   Vistara      UK       951    14:20  Delhi    02h 10m
# 8  11-02-2022  GO FIRST      G8       334    08:00  Delhi    02h 10m
# 9  11-02-2022  GO FIRST      G8       336    14:20  Delhi    02h 15m
#
#         stop arr_time      to  price
# 0  non-stop     21:05  Mumbai  5,953
# 1  non-stop     08:40  Mumbai  5,953
# 2  non-stop     06:35  Mumbai  5,956
# 3  non-stop     12:35  Mumbai  5,955
# 4  non-stop     11:10  Mumbai  5,955
# 5  non-stop     14:00  Mumbai  5,955
# 6  non-stop     11:35  Mumbai  6,060
# 7  non-stop     16:30  Mumbai  6,060
# 8  non-stop     10:10  Mumbai  5,954
# 9  non-stop     16:35  Mumbai  5,954

# %%
df_economy.duplicated().sum()
# Out:
# np.int64(2)

# %%
df_economy[df_economy.duplicated(keep=False)]
# Out:
#             date    airline ch_code  num_code dep_time   from time_taken  \
# 516   14-02-2022  Air India      AI       807    17:20  Delhi    15h 15m
# 563   14-02-2022  Air India      AI       807    17:20  Delhi    15h 15m
# 6080  13-03-2022  Air India      AI       475    13:00  Delhi    24h 35m
# 6181  13-03-2022  Air India      AI       475    13:00  Delhi    24h 35m
#
#                                                    stop arr_time      to  \
# 516   1-stop\r\n\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t...    08:35  Mumbai
# 563   1-stop\r\n\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t...    08:35  Mumbai
# 6080  1-stop\r\n\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t...    13:35  Mumbai
# 6181  1-stop\r\n\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t...    13:35  Mumbai
#
#        price
# 516   12,150
# 563   12,150
# 6080   4,780
# 6181   4,780

# %%
df_eco=df_economy.copy()

# %% [markdown]
# **Tratamiento de economy**

# %% [markdown]
# Sí, tiene bastante sentido —y de hecho es una práctica común— que una agencia de viajes intente predecir los precios de las aerolíneas. No porque puedan adivinar el futuro, sino porque anticipar tendencias les da ventajas competitivas muy claras.
#
# Por qué tiene sentido que lo hagan
# Aquí van las razones más sólidas:
#
# 📈 1. Optimizar cuándo comprar inventario
# Muchas agencias compran cupos o bloquean tarifas. Si pueden estimar cuándo los precios subirán o bajarán, pueden:
#
# Comprar más barato.
#
# Reducir riesgo de quedarse con plazas caras.
#
# Mejorar márgenes sin subir precios al cliente.
#
# 💼 2. Ofrecer mejores precios a los clientes
# Si una agencia sabe que una ruta suele bajar los martes o subir cuando se acerca un feriado, puede:
#
# Recomendar el mejor momento para reservar.
#
# Crear campañas más inteligentes.
#
# Diferenciarse de la competencia.
#
# 🤖 3. Modelos predictivos basados en datos reales
# Las aerolíneas usan yield management, un sistema dinámico que ajusta precios según:
#
# Demanda.
#
# Antelación.
#
# Temporada.
#
# Competencia.
#
# Eventos especiales.
#
# Aunque es complejo, los patrones existen, y una agencia con datos históricos puede entrenar modelos para detectar tendencias.
#
# 🧠 4. Mejorar la planificación interna
# Predicciones razonables ayudan a:
#
# Planificar ventas.
#
# Ajustar comisiones.
#
# Negociar con proveedores.
#
# Diseñar paquetes turísticos más rentables.
#
# ¿Qué tan precisas pueden ser estas predicciones?
# Aquí viene la parte interesante:
# No pueden ser perfectas, porque las aerolíneas cambian precios de forma muy dinámica y con información que solo ellas conocen.
#
# Pero sí pueden ser útiles, como una brújula: no te dice el camino exacto, pero te orienta.

# %% [markdown]
# **Simplificar airline**

# %%
df_eco.airline.value_counts(ascending= False)
# Out:
# airline
# Vistara      67270
# Air India    47996
# Indigo       43120
# GO FIRST     23177
# AirAsia      16098
# SpiceJet      9011
# StarAir         61
# Trujet          41
# Name: count, dtype: int64

# %%
df_eco.airline.value_counts(normalize= True, ascending= False)
# Out:
# airline
# Vistara      0.325331
# Air India    0.232118
# Indigo       0.208537
# GO FIRST     0.112089
# AirAsia      0.077853
# SpiceJet     0.043579
# StarAir      0.000295
# Trujet       0.000198
# Name: proportion, dtype: float64

# %%
otras = ["AirAsia", "SpiceJet", "StarAir","Trujet"]

df_eco["airline"] = df_eco["airline"].replace(otras, "Otra")

# %%
df_eco.airline.value_counts(normalize= True, ascending= False)
# Out:
# airline
# Vistara      0.325331
# Air India    0.232118
# Indigo       0.208537
# Otra         0.121925
# GO FIRST     0.112089
# Name: proportion, dtype: float64

# %% [markdown]
# Creo columna flight:
#
# - ch_code → código de aerolínea (SG, UK, I5…)
# - num_code → número de vuelo

# %%
df_eco['flight'] = df_eco['ch_code'] + df_eco['num_code'].astype(str)

# %% [markdown]
# **Convertir price a número**

# %%
df_eco['price'] = df_eco['price'].str.replace(',', '').astype(int)

# %% [markdown]
# **Limpiar time_taken**

# %%
df_eco['time_taken'].isna().sum()
# Out:
# np.int64(0)

# %%
df_eco[df_eco['time_taken'].isna()]
# Out:
# Empty DataFrame
# Columns: [date, airline, ch_code, num_code, dep_time, from, time_taken, stop, arr_time, to, price, flight]
# Index: []

# %% [markdown]
# Convierto todo a horas, pero no a “horas enteras”, sino a horas en formato decimal, que es lo que un modelo de machine learning puede entender y usar de forma correcta.

# %%
import re
import numpy as np

def convert_duration(x):
    if pd.isna(x):
        return np.nan
    
    # Buscar horas
    h = re.search(r'(\d+)h', x)
    hours = int(h.group(1)) if h else 0
    
    # Buscar minutos
    m = re.search(r'(\d+)m', x)
    minutes = int(m.group(1)) if m else 0
    
    return hours + minutes/60

df_eco['duration'] = df_eco['time_taken'].apply(convert_duration)

# %% [markdown]
# **Convertir horas (dep_time y arr_time)**

# %% [markdown]
# Convertir dep_time y arr_time a datetime
# - Tus horas vienen como strings "18:55", "06:20"…

# %%
#Primero las convertimos a datetime:
df_eco['dep_time'] = pd.to_datetime(df_eco['dep_time'], format='%H:%M')
df_eco['arr_time'] = pd.to_datetime(df_eco['arr_time'], format='%H:%M')
#Ahora extraemos la hora numérica (muy útil para ML):
df_eco['dep_hour'] = df_eco['dep_time'].dt.hour
df_eco['arr_hour'] = df_eco['arr_time'].dt.hour

# %%
df_eco['dep_hour'].unique()
# Out:
# array([18,  6,  4, 10,  8, 11,  9, 14, 15,  7, 12, 19,  5, 17, 13, 16, 21,
#        20, 22, 23,  2,  0,  1,  3], dtype=int32)

# %%
sorted(df_eco['dep_hour'].unique())
# Out:
# [np.int32(0),
#  np.int32(1),
#  np.int32(2),
#  np.int32(3),
#  np.int32(4),
#  np.int32(5),
#  np.int32(6),
#  np.int32(7),
#  np.int32(8),
#  np.int32(9),
#  np.int32(10),
#  np.int32(11),
#  np.int32(12),
#  np.int32(13),
#  np.int32(14),
#  np.int32(15),
#  np.int32(16),
#  np.int32(17),
#  np.int32(18),
#  np.int32(19),
#  np.int32(20),
#  np.int32(21),
#  np.int32(22),
#  np.int32(23)]

# %%
sorted(df_eco['arr_hour'].unique())
# Out:
# [np.int32(0),
#  np.int32(1),
#  np.int32(2),
#  np.int32(3),
#  np.int32(4),
#  np.int32(5),
#  np.int32(6),
#  np.int32(7),
#  np.int32(8),
#  np.int32(9),
#  np.int32(10),
#  np.int32(11),
#  np.int32(12),
#  np.int32(13),
#  np.int32(14),
#  np.int32(15),
#  np.int32(16),
#  np.int32(17),
#  np.int32(18),
#  np.int32(19),
#  np.int32(20),
#  np.int32(21),
#  np.int32(22),
#  np.int32(23)]

# %% [markdown]
# -Aqui vemos que en la india se vuela las 24 horas del dia no como en otros paises eurpeos y categorizamos por Late Night, Early Morning, Morning, Afternoon, Evening y Night.

# %% [markdown]
# El modelo no entiende nada si no lo cambiamos.
#
# Para él, "23:10:00" no es más grande ni más pequeño que "02:45:00".
#
# Convertirlo a datetime.time permite:
#
# - extraer la hora numérica (.dt.hour)
# - ordenar cronológicamente
# - agrupar por horas
# - detectar patrones temporales

# %%
def categorize_hour(h):
    if 0 <= h < 4:
        return 'Late Night'
    elif 4 <= h < 8:
        return 'Early Morning'
    elif 8 <= h < 12:
        return 'Morning'
    elif 12 <= h < 16:
        return 'Afternoon'
    elif 16 <= h < 20:
        return 'Evening'
    else:
        return 'Night'

df_eco['dep_time_cat'] = df_eco['dep_hour'].apply(categorize_hour)
df_eco['arr_time_cat'] = df_eco['arr_hour'].apply(categorize_hour)

# %% [markdown]
# **Days_left**
#
# Representa los dias desde que haces webscrapping hasta el dia para el cual buscas el viaje. Aqui negocio nos dice que el dia que realizamos el webscrapping es el 10 de febrero. (Esto lo tenemos que establecer nosotros porque no viene la fecha en la que realiza cada uno de los scrapeos)

# %%
df_eco['date'].dtype
# Out:
# dtype('O')

# %%
df_eco['date'] = pd.to_datetime(df_eco['date'], format="%d-%m-%Y", errors='coerce')

# %%
scraping_date = pd.to_datetime("11-02-2022", format="%d-%m-%Y")
df_eco['days_left'] = (df_eco['date'] - scraping_date).dt.days

# %%
df_eco["days_left"] = df_eco["days_left"] + 1

# %%
df_eco[df_eco['date'].isna()]
# Out:
# Empty DataFrame
# Columns: [date, airline, ch_code, num_code, dep_time, from, time_taken, stop, arr_time, to, price, flight, duration, dep_hour, arr_hour, dep_time_cat, arr_time_cat, days_left]
# Index: []

# %% [markdown]
# **Añadir la clase**
#
# Por que luego vamos a añadir la clase de economy y bussinees en un mismo dataset.

# %%
df_eco['class'] = 'economy'

# %%
df_eco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206774 entries, 0 to 206773
# Data columns (total 19 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   date          206774 non-null  datetime64[ns]
#  1   airline       206774 non-null  object
#  2   ch_code       206774 non-null  object
#  3   num_code      206774 non-null  int64
#  4   dep_time      206774 non-null  datetime64[ns]
#  5   from          206774 non-null  object
#  6   time_taken    206774 non-null  object
#  7   stop          206774 non-null  object
#  8   arr_time      206774 non-null  datetime64[ns]
#  9   to            206774 non-null  object
#  10  price         206774 non-null  int64
#  11  flight        206774 non-null  object
#  12  duration      206774 non-null  float64
#  13  dep_hour      206774 non-null  int32
#  14  arr_hour      206774 non-null  int32
#  15  dep_time_cat  206774 non-null  object
#  16  arr_time_cat  206774 non-null  object
#  17  days_left     206774 non-null  int64
#  18  class         206774 non-null  object
# dtypes: datetime64[ns](3), float64(1), int32(2), int64(3), object(10)
# memory usage: 28.4+ MB

# %% [markdown]
# **Renombrar columnas**
# - Tus columnas from y to son palabras reservadas en Python y además no son descriptivas.

# %%
df_eco = df_eco.rename(columns={
    'from': 'source_city',
    'to': 'destination_city'
})

# %%
df_eco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206774 entries, 0 to 206773
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              206774 non-null  datetime64[ns]
#  1   airline           206774 non-null  object
#  2   ch_code           206774 non-null  object
#  3   num_code          206774 non-null  int64
#  4   dep_time          206774 non-null  datetime64[ns]
#  5   source_city       206774 non-null  object
#  6   time_taken        206774 non-null  object
#  7   stop              206774 non-null  object
#  8   arr_time          206774 non-null  datetime64[ns]
#  9   destination_city  206774 non-null  object
#  10  price             206774 non-null  int64
#  11  flight            206774 non-null  object
#  12  duration          206774 non-null  float64
#  13  dep_hour          206774 non-null  int32
#  14  arr_hour          206774 non-null  int32
#  15  dep_time_cat      206774 non-null  object
#  16  arr_time_cat      206774 non-null  object
#  17  days_left         206774 non-null  int64
#  18  class             206774 non-null  object
# dtypes: datetime64[ns](3), float64(1), int32(2), int64(3), object(10)
# memory usage: 28.4+ MB

# %%
df_eco['stop'] = (
    df_eco['stop']
    .str.replace(r'\s+', ' ', regex=True)  # reemplaza tabs y saltos por espacios
    .str.strip()                           # elimina espacios al inicio y final
)

# %%
import re

def clean_stop(x):
    x = x.lower().strip()
    
    # non-stop
    if "non" in x:
        return "non-stop"
    
    # 1-stop, 2-stop, 3-stop
    match = re.search(r'(\d+)', x)
    if match:
        n = int(match.group(1))
        return f"{n}-stop"
    
    # casos raros como "2+-stop"
    if "+" in x:
        return "multi-stop"
    
    return "unknown"

df_eco['stop'] = df_eco['stop'].apply(clean_stop)

# %%
df_eco['stop'].unique()
# Out:
# array(['non-stop', '1-stop', '2-stop'], dtype=object)

# %%
# Convertir la columna 'stop' a valores numéricos
df_eco['stop_num'] = df_eco['stop'].replace({
    'non-stop': 0,
    '1-stop': 1,
    '2-stop': 2
}).astype(int)
# Out:
# C:\Users\lufue\AppData\Local\Temp\ipykernel_23852\1520666736.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_eco['stop_num'] = df_eco['stop'].replace({

# %% [markdown]
# **Eliminacion de columnas que no nos interesan**

# %%
cols_to_drop = [
    'dep_time',
    'arr_time',
    'date',
    'time_taken',
    'Unnamed: 0',
    'ch_code',
    'num_code',
    'dep_hour',
    'arr_hour',
    'flight', 
    'stop'
]

df_eco = df_eco.drop(columns=[c for c in cols_to_drop if c in df_eco.columns])

# %% [markdown]
# **Añadir unidades a los nombres de las columnas**

# %%
df_eco = df_eco.rename(columns={
    'price': 'price(Rupias)',
    'duration': 'duration(h)'
})

# %% [markdown]
# **Duplicado**

# %%
df_eco.duplicated(subset=[
    'airline', 'source_city', 'destination_city', 'stop_num',
    'class', 'duration(h)', 'dep_time_cat', 'arr_time_cat', 'days_left', 'price(Rupias)'
]).sum()
# Out:
# np.int64(1758)

# %%
dups = df_eco[df_eco.duplicated(subset=[
    'airline', 'source_city', 'destination_city', 'stop_num',
    'class', 'duration(h)', 'dep_time_cat', 'arr_time_cat', 'days_left', 'price(Rupias)'
], keep=False)]

# %%
dups.head(20)
# Out:
#        airline source_city destination_city  price(Rupias)  duration(h)  \
# 9     GO FIRST       Delhi           Mumbai           5954     2.250000
# 10    GO FIRST       Delhi           Mumbai           5954     2.250000
# 154    Vistara       Delhi           Mumbai           7530     2.166667
# 155    Vistara       Delhi           Mumbai           7530     2.166667
# 400       Otra       Delhi           Mumbai           5953     2.333333
# 401       Otra       Delhi           Mumbai           5953     2.333333
# 402       Otra       Delhi           Mumbai           5953     2.333333
# 403       Otra       Delhi           Mumbai           5953     2.333333
# 404    Vistara       Delhi           Mumbai           5955     2.166667
# 405    Vistara       Delhi           Mumbai           5955     2.166667
# 413   GO FIRST       Delhi           Mumbai           5954     2.250000
# 414   GO FIRST       Delhi           Mumbai           5954     2.250000
# 516  Air India       Delhi           Mumbai          12150    15.250000
# 563  Air India       Delhi           Mumbai          12150    15.250000
# 564       Otra       Delhi           Mumbai           5953     2.166667
# 565       Otra       Delhi           Mumbai           5953     2.166667
# 566       Otra       Delhi           Mumbai           5953     2.250000
# 567       Otra       Delhi           Mumbai           5953     2.250000
# 568       Otra       Delhi           Mumbai           5953     2.333333
# 569       Otra       Delhi           Mumbai           5953     2.333333
#
#       dep_time_cat arr_time_cat  days_left    class  stop_num
# 9        Afternoon      Evening          1  economy         0
# 10       Afternoon      Evening          1  economy         0
# 154      Afternoon      Evening          2  economy         0
# 155      Afternoon      Evening          2  economy         0
# 400  Early Morning      Morning          4  economy         0
# 401  Early Morning      Morning          4  economy         0
# 402        Evening        Night          4  economy         0
# 403        Evening        Night          4  economy         0
# 404      Afternoon      Evening          4  economy         0
# 405      Afternoon      Evening          4  economy         0
# 413      Afternoon      Evening          4  economy         0
# 414      Afternoon      Evening          4  economy         0
# 516        Evening      Morning          4  economy         1
# 563        Evening      Morning          4  economy         1
# 564        Evening        Night          5  economy         0
# 565        Evening        Night          5  economy         0
# 566  Early Morning      Morning          5  economy         0
# 567  Early Morning      Morning          5  economy         0
# 568  Early Morning      Morning          5  economy         0
# 569  Early Morning      Morning          5  economy         0

# %%
df_eco = df_eco.drop_duplicates(subset=[
    'airline', 'source_city', 'destination_city', 'stop_num',
    'class', 'duration(h)', 'dep_time_cat', 'arr_time_cat', 'days_left', 'price(Rupias)'
])

# %%
df_eco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 205016 entries, 0 to 206773
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           205016 non-null  object
#  1   source_city       205016 non-null  object
#  2   destination_city  205016 non-null  object
#  3   price(Rupias)     205016 non-null  int64
#  4   duration(h)       205016 non-null  float64
#  5   dep_time_cat      205016 non-null  object
#  6   arr_time_cat      205016 non-null  object
#  7   days_left         205016 non-null  int64
#  8   class             205016 non-null  object
#  9   stop_num          205016 non-null  int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 17.2+ MB

# %% [markdown]
# **BUSSINESS**

# %%
df_business =  pd.read_csv("../data/business.csv")
df_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93487 entries, 0 to 93486
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        93487 non-null  object
#  1   airline     93487 non-null  object
#  2   ch_code     93487 non-null  object
#  3   num_code    93487 non-null  int64
#  4   dep_time    93487 non-null  object
#  5   from        93487 non-null  object
#  6   time_taken  93487 non-null  object
#  7   stop        93487 non-null  object
#  8   arr_time    93487 non-null  object
#  9   to          93487 non-null  object
#  10  price       93487 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 7.8+ MB

# %%
df_business.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_business[df_business.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [date, airline, ch_code, num_code, dep_time, from, time_taken, stop, arr_time, to, price]
# Index: []

# %%
df_bus=df_business.copy()

# %% [markdown]
# **Tratamiento de business**

# %%
df_bus["airline"] = df_bus["airline"].replace(otras, "Otra")

# %%
df_bus['flight'] = df_bus['ch_code'] + df_bus['num_code'].astype(str)

# %%
df_bus['price'] = df_bus['price'].str.replace(',', '').astype(int)

# %%
df_bus['time_taken'].isna().sum()
# Out:
# np.int64(0)

# %%
df_bus[df_bus['time_taken'].isna()]
# Out:
# Empty DataFrame
# Columns: [date, airline, ch_code, num_code, dep_time, from, time_taken, stop, arr_time, to, price, flight]
# Index: []

# %%
import re
import numpy as np

def convert_duration(x):
    if pd.isna(x):
        return np.nan
    
    # Buscar horas
    h = re.search(r'(\d+)h', x)
    hours = int(h.group(1)) if h else 0
    
    # Buscar minutos
    m = re.search(r'(\d+)m', x)
    minutes = int(m.group(1)) if m else 0
    
    return hours + minutes/60

df_bus['duration'] = df_bus['time_taken'].apply(convert_duration)

# %%
#Primero las convertimos a datetime:
df_bus['dep_time'] = pd.to_datetime(df_bus['dep_time'], format='%H:%M')
df_bus['arr_time'] = pd.to_datetime(df_bus['arr_time'], format='%H:%M')
#Ahora extraemos la hora numérica (muy útil para ML):
df_bus['dep_hour'] = df_bus['dep_time'].dt.hour
df_bus['arr_hour'] = df_bus['arr_time'].dt.hour

# %%
df_bus['dep_hour'].unique()
# Out:
# array([18, 19, 20, 21, 17, 16,  7,  8,  9, 14,  5, 13, 12,  4, 10, 11,  6,
#        15, 22, 23,  2], dtype=int32)

# %%
def categorize_hour(h):
    if 0 <= h < 4:
        return 'Late Night'
    elif 4 <= h < 8:
        return 'Early Morning'
    elif 8 <= h < 12:
        return 'Morning'
    elif 12 <= h < 16:
        return 'Afternoon'
    elif 16 <= h < 20:
        return 'Evening'
    else:
        return 'Night'

df_bus['dep_time_cat'] = df_bus['dep_hour'].apply(categorize_hour)
df_bus['arr_time_cat'] = df_bus['arr_hour'].apply(categorize_hour)

# %%
df_bus['date'].dtype
# Out:
# dtype('O')

# %%
df_bus['date'] = pd.to_datetime(df_bus['date'], format="%d-%m-%Y", errors='coerce')

# %%
scraping_date = pd.to_datetime("11-02-2022", format="%d-%m-%Y")
df_bus['days_left'] = (df_bus['date'] - scraping_date).dt.days

# %%
df_bus["days_left"] = df_bus["days_left"] + 1

# %%
df_bus[df_bus['date'].isna()]
# Out:
# Empty DataFrame
# Columns: [date, airline, ch_code, num_code, dep_time, from, time_taken, stop, arr_time, to, price, flight, duration, dep_hour, arr_hour, dep_time_cat, arr_time_cat, days_left]
# Index: []

# %%
df_bus['class'] = 'business'

# %%
df_bus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93487 entries, 0 to 93486
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          93487 non-null  datetime64[ns]
#  1   airline       93487 non-null  object
#  2   ch_code       93487 non-null  object
#  3   num_code      93487 non-null  int64
#  4   dep_time      93487 non-null  datetime64[ns]
#  5   from          93487 non-null  object
#  6   time_taken    93487 non-null  object
#  7   stop          93487 non-null  object
#  8   arr_time      93487 non-null  datetime64[ns]
#  9   to            93487 non-null  object
#  10  price         93487 non-null  int64
#  11  flight        93487 non-null  object
#  12  duration      93487 non-null  float64
#  13  dep_hour      93487 non-null  int32
#  14  arr_hour      93487 non-null  int32
#  15  dep_time_cat  93487 non-null  object
#  16  arr_time_cat  93487 non-null  object
#  17  days_left     93487 non-null  int64
#  18  class         93487 non-null  object
# dtypes: datetime64[ns](3), float64(1), int32(2), int64(3), object(10)
# memory usage: 12.8+ MB

# %%
df_bus = df_bus.rename(columns={
    'from': 'source_city',
    'to': 'destination_city'
})

# %%
df_bus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93487 entries, 0 to 93486
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              93487 non-null  datetime64[ns]
#  1   airline           93487 non-null  object
#  2   ch_code           93487 non-null  object
#  3   num_code          93487 non-null  int64
#  4   dep_time          93487 non-null  datetime64[ns]
#  5   source_city       93487 non-null  object
#  6   time_taken        93487 non-null  object
#  7   stop              93487 non-null  object
#  8   arr_time          93487 non-null  datetime64[ns]
#  9   destination_city  93487 non-null  object
#  10  price             93487 non-null  int64
#  11  flight            93487 non-null  object
#  12  duration          93487 non-null  float64
#  13  dep_hour          93487 non-null  int32
#  14  arr_hour          93487 non-null  int32
#  15  dep_time_cat      93487 non-null  object
#  16  arr_time_cat      93487 non-null  object
#  17  days_left         93487 non-null  int64
#  18  class             93487 non-null  object
# dtypes: datetime64[ns](3), float64(1), int32(2), int64(3), object(10)
# memory usage: 12.8+ MB

# %%
df_bus['stop'] = (
    df_bus['stop']
    .str.replace(r'\s+', ' ', regex=True)  # reemplaza tabs y saltos por espacios
    .str.strip()                           # elimina espacios al inicio y final
)

# %%
import re

def clean_stop(x):
    x = x.lower().strip()
    
    # non-stop
    if "non" in x:
        return "non-stop"
    
    # 1-stop, 2-stop, 3-stop
    match = re.search(r'(\d+)', x)
    if match:
        n = int(match.group(1))
        return f"{n}-stop"
    
    # casos raros como "2+-stop"
    if "+" in x:
        return "multi-stop"
    
    return "unknown"

df_bus['stop'] = df_bus['stop'].apply(clean_stop)

# %%
df_bus['stop'].unique()
# Out:
# array(['non-stop', '1-stop', '2-stop'], dtype=object)

# %%
# Convertir la columna 'stop' a valores numéricos
df_bus['stop_num'] = df_bus['stop'].replace({
    'non-stop': 0,
    '1-stop': 1,
    '2-stop': 2
}).astype(int)
# Out:
# C:\Users\lufue\AppData\Local\Temp\ipykernel_23852\2015892334.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_bus['stop_num'] = df_bus['stop'].replace({

# %%
df_bus = df_bus.rename(columns={
    'price': 'price(Rupias)',
    'duration': 'duration(h)'
})

# %%
cols_to_drop = [
    'dep_time',
    'arr_time',
    'date',
    'time_taken',
    'Unnamed: 0',
    'ch_code',
    'num_code',
    'dep_hour',
    'arr_hour',
    'flight', 
    'stop'
]

df_bus = df_bus.drop(columns=[c for c in cols_to_drop if c in df_bus.columns])

# %%
df_bus.duplicated(subset=[
    'airline', 'source_city', 'destination_city', 'stop_num',
    'class', 'duration(h)', 'dep_time_cat', 'arr_time_cat', 'days_left', 'price(Rupias)'
]).sum()
# Out:
# np.int64(311)

# %%
dups_bus = df_bus[df_bus.duplicated(subset=[
    'airline', 'source_city', 'destination_city', 'stop_num',
    'class', 'duration(h)', 'dep_time_cat', 'arr_time_cat', 'days_left', 'price(Rupias)'
], keep=False)]

# %%
dups_bus.head(10)
# Out:
#       airline source_city destination_city  price(Rupias)  duration(h)  \
# 4791  Vistara       Delhi           Mumbai          36712     2.333333
# 4792  Vistara       Delhi           Mumbai          36712     2.333333
# 4900  Vistara       Delhi           Mumbai          36712     2.333333
# 4901  Vistara       Delhi           Mumbai          36712     2.333333
# 5013  Vistara       Delhi           Mumbai          36712     2.333333
# 5014  Vistara       Delhi           Mumbai          36712     2.333333
# 5329  Vistara       Delhi        Bangalore          33979     2.750000
# 5330  Vistara       Delhi        Bangalore          33979     2.750000
# 5333  Vistara       Delhi        Bangalore          33979     2.833333
# 5334  Vistara       Delhi        Bangalore          33979     2.833333
#
#      dep_time_cat arr_time_cat  days_left     class  stop_num
# 4791      Evening        Night         45  business         0
# 4792      Evening        Night         45  business         0
# 4900      Evening        Night         46  business         0
# 4901      Evening        Night         46  business         0
# 5013      Evening        Night         47  business         0
# 5014      Evening        Night         47  business         0
# 5329      Morning      Morning          2  business         0
# 5330      Morning      Morning          2  business         0
# 5333      Evening        Night          2  business         0
# 5334      Evening        Night          2  business         0

# %%
df_bus = df_bus.drop_duplicates(subset=[
    'airline', 'source_city', 'destination_city', 'stop_num',
    'class', 'duration(h)', 'dep_time_cat', 'arr_time_cat', 'days_left', 'price(Rupias)'
])

# %%
df_bus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 93176 entries, 0 to 93486
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   airline           93176 non-null  object
#  1   source_city       93176 non-null  object
#  2   destination_city  93176 non-null  object
#  3   price(Rupias)     93176 non-null  int64
#  4   duration(h)       93176 non-null  float64
#  5   dep_time_cat      93176 non-null  object
#  6   arr_time_cat      93176 non-null  object
#  7   days_left         93176 non-null  int64
#  8   class             93176 non-null  object
#  9   stop_num          93176 non-null  int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 7.8+ MB

# %%
df_final = pd.concat([df_eco, df_bus], ignore_index=True)

# %%
df_final
# Out:
#         airline source_city destination_city  price(Rupias)  duration(h)  \
# 0          Otra       Delhi           Mumbai           5953     2.166667
# 1          Otra       Delhi           Mumbai           5953     2.333333
# 2          Otra       Delhi           Mumbai           5956     2.166667
# 3       Vistara       Delhi           Mumbai           5955     2.250000
# 4       Vistara       Delhi           Mumbai           5955     2.333333
# ...         ...         ...              ...            ...          ...
# 298187  Vistara     Chennai        Hyderabad          69265    10.083333
# 298188  Vistara     Chennai        Hyderabad          77105    10.416667
# 298189  Vistara     Chennai        Hyderabad          79099    13.833333
# 298190  Vistara     Chennai        Hyderabad          81585    10.000000
# 298191  Vistara     Chennai        Hyderabad          81585    10.083333
#
#          dep_time_cat   arr_time_cat  days_left     class  stop_num
# 0             Evening          Night          1   economy         0
# 1       Early Morning        Morning          1   economy         0
# 2       Early Morning  Early Morning          1   economy         0
# 3             Morning      Afternoon          1   economy         0
# 4             Morning        Morning          1   economy         0
# ...               ...            ...        ...       ...       ...
# 298187        Morning        Evening         49  business         1
# 298188      Afternoon          Night         49  business         1
# 298189  Early Morning          Night         49  business         1
# 298190  Early Morning        Evening         49  business         1
# 298191        Morning        Evening         49  business         1
#
# [298192 rows x 10 columns]

# %%
df_final = df_final.drop_duplicates()

# %%
df_final.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_final[df_final.duplicated()]
# Out:
# Empty DataFrame
# Columns: [airline, source_city, destination_city, price(Rupias), duration(h), dep_time_cat, arr_time_cat, days_left, class, stop_num]
# Index: []

# %%
df_final['price(Rupias)'] = df_final['price(Rupias)'].astype(float)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298192 entries, 0 to 298191
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           298192 non-null  object
#  1   source_city       298192 non-null  object
#  2   destination_city  298192 non-null  object
#  3   price(Rupias)     298192 non-null  float64
#  4   duration(h)       298192 non-null  float64
#  5   dep_time_cat      298192 non-null  object
#  6   arr_time_cat      298192 non-null  object
#  7   days_left         298192 non-null  int64
#  8   class             298192 non-null  object
#  9   stop_num          298192 non-null  int64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 22.8+ MB

# %%
df_final.shape
# Out:
# (298192, 10)

# %% [markdown]
# **Separar en Train y Test**

# %%
train_set, test_set = train_test_split(df_final, test_size= 0.2, random_state= 42)

# %%
train_set_copy = train_set.copy()
test_set_copy = test_set.copy()

# %% [markdown]
# **Análisis del target para regresión**

# %%
target_reg = "price(Rupias)"

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_final[target_reg], bins=50, kde=True, color='royalblue')
plt.title("Distribución de la variable target: price")
plt.xlabel("Precio del vuelo")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# *'Price' presenta una distribución asimétrica. Hay un pico en valores bajos (clase económica) y una concentración entre 40.000 y 80.000 (que puede ser debido a la clase business). Miro la distribución según la clase:*

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_final[df_final["class"] == "economy"][target_reg], bins=50, kde=True, label = "Economy")
sns.histplot(df_final[df_final["class"] == "business"][target_reg], bins=50, kde=True, label = "Business")
plt.title("Distribución de Price por clase")
plt.xlabel("Price(Rupias)")
plt.legend()
plt.show()

# %% [markdown]
# **MINI-EDA**

# %%
df_final.columns
# Out:
# Index(['airline', 'source_city', 'destination_city', 'price(Rupias)',
#        'duration(h)', 'dep_time_cat', 'arr_time_cat', 'days_left', 'class',
#        'stop_num'],
#       dtype='object')

# %%
features_num_reg = ["duration(h)", "days_left", "stop_num"]
print(features_num_reg)

features_cat_reg = [col for col in df_final.columns if col not in features_num_reg and col != target_reg]
print(features_cat_reg)

features = features_num_reg + features_cat_reg
# Out:
# ['duration(h)', 'days_left', 'stop_num']
# ['airline', 'source_city', 'destination_city', 'dep_time_cat', 'arr_time_cat', 'class']

# %% [markdown]
# Categóricas vs target_reg

# %%
for col_cat in features_cat_reg:
    bt.plot_grouped_histograms(train_set, cat_col= col_cat, num_col= target_reg, group_size= train_set[col_cat].nunique())

# %% [markdown]
# *Las distribuciones de 'dep_time_cat' y 'arr_time_cat' son las que más superpuestas parecen*.

# %% [markdown]
# Lo hago también con el test ANOVA para decidir si me quedo todas o no.

# %%
for cat_col in features_cat_reg:
    valores_unicos = train_set[cat_col].unique()
    target_por_cat_col = [train_set[train_set[cat_col] == categoria][target_reg] for categoria in valores_unicos]

    f_val, p_val = stats.f_oneway(*target_por_cat_col)
    print(f"{cat_col}:")
    print(f"\t Valor de F: {f_val}")
    print(f"\t p-valor: {p_val}")
# Out:
# airline:
# 	 Valor de F: 17081.57235488204
# 	 p-valor: 0.0
# source_city:
# 	 Valor de F: 111.43991654629089
# 	 p-valor: 4.913557666382573e-118
# destination_city:
# 	 Valor de F: 142.45408569181038
# 	 p-valor: 1.8474400472304373e-151
# dep_time_cat:
# 	 Valor de F: 258.3793846974706
# 	 p-valor: 2.0616262378244465e-276
# arr_time_cat:
# 	 Valor de F: 762.2266222223897
# 	 p-valor: 0.0
# class:
# 	 Valor de F: 1753340.457890602
# 	 p-valor: 0.0

# %% [markdown]
# *Todos los p-valores son muy pequeños (p-valor < 0.01), se puede rechazar la hipótesis nula de que no existe relación entre las variables, así que me quedo con todas.*

# %% [markdown]
# Numéricas vs target_reg

# %%
# Correlaciones
corr = train_set[features_num_reg + [target_reg]].corr()
serie_corr = np.abs(corr[target_reg]).sort_values(ascending = False)
serie_corr
# Out:
# price(Rupias)    1.000000
# duration(h)      0.200939
# stop_num         0.114994
# days_left        0.091964
# Name: price(Rupias), dtype: float64

# %%
plt.figure()
sns.heatmap(corr, annot= True, cmap = "Blues", vmin= -1, vmax= 1);

# %% [markdown]
# - *No correla mucho ninguna variable con el target.*
# - *Entre 'stop_num' y 'duration' sí hay cierta colinealidad.*

# %% [markdown]
# Como son muy pocas y 0.46 no es mucho, creo que es mejor quedarse con todas.

# %% [markdown]
# **Tratamiento de features**

# %% [markdown]
# Categóricas

# %%
features_cat_reg
# Out:
# ['airline',
#  'source_city',
#  'destination_city',
#  'dep_time_cat',
#  'arr_time_cat',
#  'class']

# %%
ord_encoder = OrdinalEncoder(categories= [["economy", "business"]])
train_set["class"] = ord_encoder.fit_transform(train_set[["class"]])
test_set["class"] = ord_encoder.transform(test_set[["class"]])

# %%
OH_encoder = OneHotEncoder(handle_unknown="ignore", sparse_output=False)

cat_cols = [col for col in features_cat_reg if col != "class"]

train_encod = OH_encoder.fit_transform(train_set[cat_cols])
test_encod = OH_encoder.transform(test_set[cat_cols])

# Convertimos a DataFrame con nombres de columna
col_names = OH_encoder.get_feature_names_out(cat_cols)
train_encod_df = pd.DataFrame(train_encod, columns = col_names, index = train_set.index)
test_encod_df = pd.DataFrame(test_encod, columns = col_names, index = test_set.index)

# %%
resto_cols = [col for col in features if col not in cat_cols]
resto_cols
# Out:
# ['duration(h)', 'days_left', 'stop_num', 'class']

# %%
train_set = pd.concat([train_set[resto_cols + [target_reg]], train_encod_df], axis = 1)
test_set = pd.concat([test_set[resto_cols + [target_reg]], test_encod_df], axis = 1)

# %%
print(train_set.shape)
print(test_set.shape)
# Out:
# (238553, 34)
# (59639, 34)

# %%
train_set.head()
# Out:
#         duration(h)  days_left  stop_num  class  price(Rupias)  \
# 239454    17.583333         48         1    1.0        45693.0
# 21379     12.750000         12         1    0.0         5954.0
# 262332    21.500000          7         1    1.0        50271.0
# 85586     11.166667         15         1    0.0        10954.0
# 58841      1.750000         40         0    0.0         2074.0
#
#         airline_Air India  airline_GO FIRST  airline_Indigo  airline_Otra  \
# 239454                1.0               0.0             0.0           0.0
# 21379                 0.0               1.0             0.0           0.0
# 262332                1.0               0.0             0.0           0.0
# 85586                 0.0               0.0             0.0           0.0
# 58841                 0.0               0.0             0.0           0.0
#
#         airline_Vistara  ...  dep_time_cat_Evening  dep_time_cat_Late Night  \
# 239454              0.0  ...                   0.0                      0.0
# 21379               0.0  ...                   1.0                      0.0
# 262332              0.0  ...                   0.0                      0.0
# 85586               1.0  ...                   0.0                      0.0
# 58841               1.0  ...                   1.0                      0.0
#
#         dep_time_cat_Morning  dep_time_cat_Night  arr_time_cat_Afternoon  \
# 239454                   0.0                 0.0                     0.0
# 21379                    0.0                 0.0                     0.0
# 262332                   0.0                 1.0                     0.0
# 85586                    1.0                 0.0                     0.0
# 58841                    0.0                 0.0                     0.0
#
#         arr_time_cat_Early Morning  arr_time_cat_Evening  \
# 239454                         0.0                   0.0
# 21379                          0.0                   0.0
# 262332                         0.0                   1.0
# 85586                          0.0                   0.0
# 58841                          0.0                   1.0
#
#         arr_time_cat_Late Night  arr_time_cat_Morning  arr_time_cat_Night
# 239454                      0.0                   1.0                 0.0
# 21379                       0.0                   1.0                 0.0
# 262332                      0.0                   0.0                 0.0
# 85586                       0.0                   0.0                 1.0
# 58841                       0.0                   0.0                 0.0
#
# [5 rows x 34 columns]

# %% [markdown]
# Numéricas

# %%
# train_set_scaled = train_set.copy()
# test_set_scaled = test_set.copy()

# %%
# train_set[features_num_reg].hist()
# plt.tight_layout()

# %%
# train_set["duration(h)"].apply(np.log).hist();

# %%
# # Aplico logaritmo a duration
# train_set_scaled["duration(h)"] = np.log(train_set_scaled["duration(h)"])
# test_set_scaled["duration(h)"] = np.log(test_set_scaled["duration(h)"])

# %% [markdown]
# Escalado

# %%
# scaler = StandardScaler()
# train_set_scaled[features_num_reg] = scaler.fit_transform(train_set_scaled[features_num_reg])
# test_set_scaled[features_num_reg] = scaler.transform(test_set_scaled[features_num_reg])

# %%
# train_set_scaled[features_num_reg].describe()

# %% [markdown]
# **Modelado**

# %% [markdown]
# Parejas X e y

# %%
X_train = train_set.drop(columns= target_reg, axis = 1)
# X_train_scaled = train_set_scaled.drop(columns= target_reg, axis = 1)
y_train = train_set[target_reg]

X_test = test_set.drop(columns= target_reg, axis = 1)
# X_test_scaled = test_set_scaled.drop(columns= target_reg, axis = 1)
y_test = test_set[target_reg]

# %% [markdown]
# Baseline

# %%
rf_reg = RandomForestRegressor(max_depth = 5, random_state= 42)

# %% [markdown]
# Comparación

# %%
rf_reg = RandomForestRegressor(max_depth = 5, random_state= 42)
lgb_reg = LGBMRegressor(max_depth = 5, random_state = 42, verbose = -1)
xgb_reg = XGBRegressor(max_depth = 5, random_state = 42)

modelos_reg = {
    "Random Forest": rf_reg,
    "LightGBM": lgb_reg,
    "XGBoost Regressor": xgb_reg
}

model_set = [rf_reg, xgb_reg, lgb_reg]

# %%
metricas_cv = {}

scoring = {
    "rmse": "neg_root_mean_squared_error",
    "mae": "neg_mean_absolute_error",
    "r2": "r2"
}

for nombre, modelo in zip(modelos_reg, model_set):
    valores = cross_validate(modelo, X_train, y_train, cv = 5, scoring = scoring)
    metricas_cv[nombre] = valores


for model_name, valores in metricas_cv.items():
    rmse = -np.mean(valores["test_rmse"])
    mae = -np.mean(valores["test_mae"])
    r2 = np.mean(valores["test_r2"])

    print(f"Model <{model_name}>:")
    print(f"\t RMSE_CV: {rmse}")
    print(f"\t MAE_CV: {mae}")
    print(f"\t R2-score_CV: {r2}")
# Out:
# Model <Random Forest>:
# 	 RMSE_CV: 4358.474523842826
# 	 MAE_CV: 2418.2658451118746
# 	 R2-score_CV: 0.9632328439343378
# Model <LightGBM>:
# 	 RMSE_CV: 2575.3553779523227
# 	 MAE_CV: 1295.5791386706885
# 	 R2-score_CV: 0.9871630920302332
# Model <XGBoost Regressor>:
# 	 RMSE_CV: 3945.1858538025454
# 	 MAE_CV: 2341.803115452183
# 	 R2-score_CV: 0.9698747463915913

# %% [markdown]
# *El mejor en todas las métricas es LightGBM*

# %%
param_grid_lgb = {
    "n_estimators": [100,200],
    "learning_rate": [0.1,0.5,1],
    "max_depth": [5,10,15],
    "min_data_in_leaf": [1,10,20,100]
}

lgb_reg = LGBMRegressor(verbose = -1)

lgb_grid = GridSearchCV(lgb_reg,
                        param_grid= param_grid_lgb,
                        cv = 5,
                        scoring= "neg_root_mean_squared_error",
                        n_jobs=-1)

lgb_grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=LGBMRegressor(verbose=-1), n_jobs=-1,
#              param_grid={'learning_rate': [0.1, 0.5, 1],
#                          'max_depth': [5, 10, 15],
#                          'min_data_in_leaf': [1, 10, 20, 100],
#                          'n_estimators': [100, 200]},
#              scoring='neg_root_mean_squared_error')

# %%
-lgb_grid.best_score_
# Out:
# np.float64(2920.6729414321503)

# %%
lgb_grid.best_params_
# Out:
# {'learning_rate': 0.5,
#  'max_depth': 15,
#  'min_data_in_leaf': 10,
#  'n_estimators': 200}

# %%
y_pred_test = lgb_grid.best_estimator_.predict(X_test)
print("RMSE:", root_mean_squared_error(y_test, y_pred_test))
print("MAE:", mean_absolute_error(y_test, y_pred_test))
print("R2:", r2_score(y_test, y_pred_test))
# Out:
# RMSE: 2906.9205619190316
# MAE: 1653.369112264242
# R2: 0.9836332795919495

# %%
def plot_predictions_vs_actual(y_real, y_pred):
    """
    Función para graficar los valores reales vs. los valores predichos en una regresión.

    Args:
    y_real (array-like): Valores reales de la variable objetivo.
    y_pred (array-like): Valores predichos de la variable objetivo.
    """
    plt.figure(figsize=(8, 6))
    plt.scatter(y_pred, y_real, alpha=0.5)
    plt.xlabel("Valores Predichos")
    plt.ylabel("Valores Reales")

    # Línea y=x
    max_value = max(max(y_real), max(y_pred))
    min_value = min(min(y_real), min(y_pred))
    plt.plot([min_value, max_value], [min_value, max_value], 'r')

    plt.title("Comparación de Valores Reales vs. Predichos")
    plt.show()

# %%
plot_predictions_vs_actual(y_test, y_pred_test)

# %% [markdown]
# **Optimización con optuna**

# %%
# Definir función objetivo para Optuna

def objective(trial):
    param_grid = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 800),
        "max_depth": trial.suggest_int("max_depth", 3, 8),  # 5 y 15
        "num_leaves": trial.suggest_int("num_leaves", 7, 260),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.1), # 0.05 y 1
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 50, 300) # 10 y 200
    }

    model = LGBMRegressor(**param_grid, random_state= 42, verbose = -1)

    score = cross_val_score(
        model,
        X_train,
        y_train,
        cv = 5,
        scoring = "neg_root_mean_squared_error",
        n_jobs = -1
    ).mean()

    return -score

# %%
# Crear y ejecutar estudy de Optuna
study = optuna.create_study(direction = "minimize",
                            sampler = optuna.samplers.TPESampler(seed = 42))
# Out:
# [I 2026-02-26 20:22:11,406] A new study created in memory with name: no-name-ed53bb79-2d32-466d-b5d0-2e8162d26557

# %%
study.optimize(objective, n_trials= 200) # optimizar el estudio
# Out:
# [I 2026-02-25 11:15:06,984] Trial 0 finished with value: 2679.1336040451724 and parameters: {'n_estimators': 362, 'max_depth': 15, 'num_leaves': 192, 'learning_rate': 0.6187255599871848, 'min_data_in_leaf': 39}. Best is trial 0 with value: 2679.1336040451724.
# [I 2026-02-25 11:15:21,308] Trial 1 finished with value: 3431.061472453521 and parameters: {'n_estimators': 209, 'max_depth': 5, 'num_leaves': 227, 'learning_rate': 0.6210592611560484, 'min_data_in_leaf': 145}. Best is trial 0 with value: 2679.1336040451724.
# [I 2026-02-25 11:15:39,056] Trial 2 finished with value: 2763.3814526911847 and parameters: {'n_estimators': 114, 'max_depth': 15, 'num_leaves': 218, 'learning_rate': 0.25172215514436236, 'min_data_in_leaf': 44}. Best is trial 0 with value: 2679.1336040451724.
# [I 2026-02-25 11:15:55,060] Trial 3 finished with value: 2775.3930370361604 and parameters: {'n_estimators': 228, 'max_depth': 8, 'num_leaves': 140, 'learning_rate': 0.46034776771000996, 'min_data_in_leaf': 65}. Best is trial 0 with value: 2679.1336040451724.
# [I 2026-02-25 11:16:13,058] Trial 4 finished with value: 2929.9405535683773 and parameters: {'n_estimators': 528, 'max_depth': 6, 'num_leaves': 81, 'learning_rate': 0.3980437511290071, 'min_data_in_leaf': 97}. Best is trial 0 with value: 2679.1336040451724.
# [I 2026-02-25 11:16:46,110] Trial 5 finished with value: 2642.5836490765173 and parameters: {'n_estimators': 650, 'max_depth': 7, 'num_leaves': 137, 'learning_rate': 0.6127938404189404, 'min_data_in_leaf': 18}. Best is trial 5 with value: 2642.5836490765173.
# [I 2026-02-25 11:16:59,237] Trial 6 finished with value: 3068.274437270192 and parameters: {'n_estimators': 525, 'max_depth': 6, 'num_leaves': 23, 'learning_rate': 0.9514412603906666, 'min_data_in_leaf': 194}. Best is trial 5 with value: 2642.5836490765173.
# [I 2026-02-25 11:17:12,769] Trial 7 finished with value: 2813.0373010190133 and parameters: {'n_estimators': 666, 'max_depth': 8, 'num_leaves': 31, 'learning_rate': 0.700021375186549, 'min_data_in_leaf': 94}. Best is trial 5 with value: 2642.5836490765173.
# [I 2026-02-25 11:17:16,693] Trial 8 finished with value: 3316.7794507650774 and parameters: {'n_estimators': 185, 'max_depth': 10, 'num_leaves': 15, 'learning_rate': 0.9138543819748429, 'min_data_in_leaf': 59}. Best is trial 5 with value: 2642.5836490765173.
# [I 2026-02-25 11:17:43,829] Trial 9 finished with value: 2643.06702264259 and parameters: {'n_estimators': 564, 'max_depth': 8, 'num_leaves': 139, 'learning_rate': 0.5693747653761156, 'min_data_in_leaf': 45}. Best is trial 5 with value: 2642.5836490765173.
# [I 2026-02-25 11:18:10,440] Trial 10 finished with value: 2753.6818618616217 and parameters: {'n_estimators': 783, 'max_depth': 12, 'num_leaves': 88, 'learning_rate': 0.06706378183407874, 'min_data_in_leaf': 12}. Best is trial 5 with value: 2642.5836490765173.
# [I 2026-02-25 11:18:44,603] Trial 11 finished with value: 2764.3332422333256 and parameters: {'n_estimators': 654, 'max_depth': 9, 'num_leaves': 143, 'learning_rate': 0.7574278544781987, 'min_data_in_leaf': 11}. Best is trial 5 with value: 2642.5836490765173.
# [I 2026-02-25 11:19:28,467] Trial 12 finished with value: 2645.058922015965 and parameters: {'n_estimators': 647, 'max_depth': 11, 'num_leaves': 178, 'learning_rate': 0.3512565228137928, 'min_data_in_leaf': 139}. Best is trial 5 with value: 2642.5836490765173.
# [I 2026-02-25 11:19:48,586] Trial 13 finished with value: 2735.876726477246 and parameters: {'n_estimators': 420, 'max_depth': 7, 'num_leaves': 87, 'learning_rate': 0.793759619231981, 'min_data_in_leaf': 30}. Best is trial 5 with value: 2642.5836490765173.
# [I 2026-02-25 11:20:23,848] Trial 14 finished with value: 2653.2385657194545 and parameters: {'n_estimators': 776, 'max_depth': 13, 'num_leaves': 115, 'learning_rate': 0.5522622502998228, 'min_data_in_leaf': 76}. Best is trial 5 with value: 2642.5836490765173.
# [I 2026-02-25 11:20:55,526] Trial 15 finished with value: 2737.8271489882763 and parameters: {'n_estimators': 568, 'max_depth': 9, 'num_leaves': 259, 'learning_rate': 0.22815599986169888, 'min_data_in_leaf': 122}. Best is trial 5 with value: 2642.5836490765173.
# [I 2026-02-25 11:21:05,244] Trial 16 finished with value: 3128.560826219376 and parameters: {'n_estimators': 342, 'max_depth': 5, 'num_leaves': 168, 'learning_rate': 0.5350563555141926, 'min_data_in_leaf': 30}. Best is trial 5 with value: 2642.5836490765173.
# [I 2026-02-25 11:21:33,813] Trial 17 finished with value: 2758.0493310851634 and parameters: {'n_estimators': 602, 'max_depth': 7, 'num_leaves': 114, 'learning_rate': 0.8426765728904431, 'min_data_in_leaf': 78}. Best is trial 5 with value: 2642.5836490765173.
# [I 2026-02-25 11:21:53,694] Trial 18 finished with value: 2676.573114172197 and parameters: {'n_estimators': 691, 'max_depth': 10, 'num_leaves': 55, 'learning_rate': 0.6480633599408631, 'min_data_in_leaf': 50}. Best is trial 5 with value: 2642.5836490765173.
# [I 2026-02-25 11:22:16,793] Trial 19 finished with value: 2593.1402466877385 and parameters: {'n_estimators': 440, 'max_depth': 8, 'num_leaves': 155, 'learning_rate': 0.4533085804569381, 'min_data_in_leaf': 13}. Best is trial 19 with value: 2593.1402466877385.
# [I 2026-02-25 11:22:36,132] Trial 20 finished with value: 2997.7687060727126 and parameters: {'n_estimators': 459, 'max_depth': 7, 'num_leaves': 161, 'learning_rate': 0.29922663670572347, 'min_data_in_leaf': 175}. Best is trial 19 with value: 2593.1402466877385.
# [I 2026-02-25 11:22:55,089] Trial 21 finished with value: 2604.240098820823 and parameters: {'n_estimators': 476, 'max_depth': 8, 'num_leaves': 120, 'learning_rate': 0.46520932806977033, 'min_data_in_leaf': 22}. Best is trial 19 with value: 2593.1402466877385.
# [I 2026-02-25 11:23:16,711] Trial 22 finished with value: 2594.817340310848 and parameters: {'n_estimators': 448, 'max_depth': 9, 'num_leaves': 108, 'learning_rate': 0.460123110205507, 'min_data_in_leaf': 10}. Best is trial 19 with value: 2593.1402466877385.
# [I 2026-02-25 11:23:35,778] Trial 23 finished with value: 2605.8297395993277 and parameters: {'n_estimators': 444, 'max_depth': 9, 'num_leaves': 113, 'learning_rate': 0.44013271249333474, 'min_data_in_leaf': 30}. Best is trial 19 with value: 2593.1402466877385.
# [I 2026-02-25 11:23:47,009] Trial 24 finished with value: 2672.330940297335 and parameters: {'n_estimators': 352, 'max_depth': 11, 'num_leaves': 62, 'learning_rate': 0.4866517301948459, 'min_data_in_leaf': 24}. Best is trial 19 with value: 2593.1402466877385.
# [I 2026-02-25 11:24:01,729] Trial 25 finished with value: 2854.31526251376 and parameters: {'n_estimators': 301, 'max_depth': 9, 'num_leaves': 106, 'learning_rate': 0.19892475062272463, 'min_data_in_leaf': 63}. Best is trial 19 with value: 2593.1402466877385.
# [I 2026-02-25 11:24:32,245] Trial 26 finished with value: 2564.021415815211 and parameters: {'n_estimators': 476, 'max_depth': 10, 'num_leaves': 204, 'learning_rate': 0.3692183583349684, 'min_data_in_leaf': 18}. Best is trial 26 with value: 2564.021415815211.
# [I 2026-02-25 11:24:56,192] Trial 27 finished with value: 2587.8753893728867 and parameters: {'n_estimators': 401, 'max_depth': 11, 'num_leaves': 200, 'learning_rate': 0.13166166979678812, 'min_data_in_leaf': 13}. Best is trial 26 with value: 2564.021415815211.
# [I 2026-02-25 11:25:27,537] Trial 28 finished with value: 2915.3057401935457 and parameters: {'n_estimators': 410, 'max_depth': 13, 'num_leaves': 201, 'learning_rate': 0.059532499182977705, 'min_data_in_leaf': 81}. Best is trial 26 with value: 2564.021415815211.
# [I 2026-02-25 11:25:46,055] Trial 29 finished with value: 2669.6894745556797 and parameters: {'n_estimators': 286, 'max_depth': 14, 'num_leaves': 195, 'learning_rate': 0.16122823551643256, 'min_data_in_leaf': 36}. Best is trial 26 with value: 2564.021415815211.
# [I 2026-02-25 11:26:18,876] Trial 30 finished with value: 2664.4485876361514 and parameters: {'n_estimators': 397, 'max_depth': 11, 'num_leaves': 243, 'learning_rate': 0.1293866777262109, 'min_data_in_leaf': 52}. Best is trial 26 with value: 2564.021415815211.
# [I 2026-02-25 11:26:49,578] Trial 31 finished with value: 2543.290714646003 and parameters: {'n_estimators': 491, 'max_depth': 10, 'num_leaves': 207, 'learning_rate': 0.34415726979799877, 'min_data_in_leaf': 12}. Best is trial 31 with value: 2543.290714646003.
# [I 2026-02-25 11:27:25,934] Trial 32 finished with value: 2575.805667847332 and parameters: {'n_estimators': 478, 'max_depth': 10, 'num_leaves': 214, 'learning_rate': 0.3319411551842825, 'min_data_in_leaf': 37}. Best is trial 31 with value: 2543.290714646003.
# [I 2026-02-25 11:28:08,601] Trial 33 finished with value: 2569.6288491445034 and parameters: {'n_estimators': 517, 'max_depth': 10, 'num_leaves': 216, 'learning_rate': 0.3161158690279581, 'min_data_in_leaf': 39}. Best is trial 31 with value: 2543.290714646003.
# [I 2026-02-25 11:28:49,220] Trial 34 finished with value: 2567.9939523240723 and parameters: {'n_estimators': 517, 'max_depth': 10, 'num_leaves': 228, 'learning_rate': 0.30948036361300857, 'min_data_in_leaf': 40}. Best is trial 31 with value: 2543.290714646003.
# [I 2026-02-25 11:29:29,285] Trial 35 finished with value: 2568.318614048171 and parameters: {'n_estimators': 503, 'max_depth': 10, 'num_leaves': 232, 'learning_rate': 0.269845567666002, 'min_data_in_leaf': 40}. Best is trial 31 with value: 2543.290714646003.
# [I 2026-02-25 11:30:11,601] Trial 36 finished with value: 2568.007876067007 and parameters: {'n_estimators': 605, 'max_depth': 12, 'num_leaves': 232, 'learning_rate': 0.2629335100246489, 'min_data_in_leaf': 53}. Best is trial 31 with value: 2543.290714646003.
# [I 2026-02-25 11:31:02,332] Trial 37 finished with value: 2620.194310415165 and parameters: {'n_estimators': 589, 'max_depth': 12, 'num_leaves': 254, 'learning_rate': 0.3844053799970916, 'min_data_in_leaf': 115}. Best is trial 31 with value: 2543.290714646003.
# [I 2026-02-25 11:31:51,659] Trial 38 finished with value: 2604.9720470765387 and parameters: {'n_estimators': 733, 'max_depth': 12, 'num_leaves': 236, 'learning_rate': 0.40714898250941634, 'min_data_in_leaf': 54}. Best is trial 31 with value: 2543.290714646003.
# [I 2026-02-25 11:32:32,339] Trial 39 finished with value: 2588.735821524378 and parameters: {'n_estimators': 620, 'max_depth': 13, 'num_leaves': 187, 'learning_rate': 0.26563553507618803, 'min_data_in_leaf': 68}. Best is trial 31 with value: 2543.290714646003.
# [I 2026-02-25 11:33:08,289] Trial 40 finished with value: 2580.2507360179443 and parameters: {'n_estimators': 526, 'max_depth': 15, 'num_leaves': 219, 'learning_rate': 0.37127270441673843, 'min_data_in_leaf': 25}. Best is trial 31 with value: 2543.290714646003.
# [I 2026-02-25 11:33:45,859] Trial 41 finished with value: 2571.3255986639024 and parameters: {'n_estimators': 492, 'max_depth': 11, 'num_leaves': 233, 'learning_rate': 0.2771841050067595, 'min_data_in_leaf': 46}. Best is trial 31 with value: 2543.290714646003.
# [I 2026-02-25 11:34:22,350] Trial 42 finished with value: 2652.333653601427 and parameters: {'n_estimators': 558, 'max_depth': 10, 'num_leaves': 224, 'learning_rate': 0.21841256289022157, 'min_data_in_leaf': 89}. Best is trial 31 with value: 2543.290714646003.
# [I 2026-02-25 11:35:02,840] Trial 43 finished with value: 2565.235595903431 and parameters: {'n_estimators': 509, 'max_depth': 12, 'num_leaves': 242, 'learning_rate': 0.16630584691689745, 'min_data_in_leaf': 39}. Best is trial 31 with value: 2543.290714646003.
# [I 2026-02-25 11:36:15,300] Trial 44 finished with value: 2646.629973996013 and parameters: {'n_estimators': 563, 'max_depth': 12, 'num_leaves': 249, 'learning_rate': 0.10026610322266521, 'min_data_in_leaf': 58}. Best is trial 31 with value: 2543.290714646003.
# [I 2026-02-25 11:36:56,310] Trial 45 finished with value: 2523.89345116859 and parameters: {'n_estimators': 540, 'max_depth': 14, 'num_leaves': 208, 'learning_rate': 0.17036901440687074, 'min_data_in_leaf': 18}. Best is trial 45 with value: 2523.89345116859.
# [I 2026-02-25 11:37:36,031] Trial 46 finished with value: 2525.856667086891 and parameters: {'n_estimators': 539, 'max_depth': 14, 'num_leaves': 209, 'learning_rate': 0.1789865456605218, 'min_data_in_leaf': 21}. Best is trial 45 with value: 2523.89345116859.
# [I 2026-02-25 11:38:11,215] Trial 47 finished with value: 2520.167983898175 and parameters: {'n_estimators': 541, 'max_depth': 14, 'num_leaves': 208, 'learning_rate': 0.20468159768466926, 'min_data_in_leaf': 18}. Best is trial 47 with value: 2520.167983898175.
# [I 2026-02-25 11:38:39,956] Trial 48 finished with value: 2529.2989776140903 and parameters: {'n_estimators': 550, 'max_depth': 14, 'num_leaves': 181, 'learning_rate': 0.18890106044487193, 'min_data_in_leaf': 18}. Best is trial 47 with value: 2520.167983898175.
# [I 2026-02-25 11:39:09,202] Trial 49 finished with value: 2534.484679246285 and parameters: {'n_estimators': 547, 'max_depth': 14, 'num_leaves': 175, 'learning_rate': 0.18190907289556607, 'min_data_in_leaf': 20}. Best is trial 47 with value: 2520.167983898175.
# [I 2026-02-25 11:39:17,153] Trial 50 finished with value: 2867.6794346223314 and parameters: {'n_estimators': 116, 'max_depth': 14, 'num_leaves': 174, 'learning_rate': 0.1796091325467143, 'min_data_in_leaf': 28}. Best is trial 47 with value: 2520.167983898175.
# [I 2026-02-25 11:39:48,591] Trial 51 finished with value: 2586.1205470082923 and parameters: {'n_estimators': 543, 'max_depth': 14, 'num_leaves': 185, 'learning_rate': 0.10612177792457314, 'min_data_in_leaf': 20}. Best is trial 47 with value: 2520.167983898175.
# [I 2026-02-25 11:40:26,834] Trial 52 finished with value: 2514.374150394341 and parameters: {'n_estimators': 630, 'max_depth': 14, 'num_leaves': 209, 'learning_rate': 0.22859466237502363, 'min_data_in_leaf': 18}. Best is trial 52 with value: 2514.374150394341.
# [I 2026-02-25 11:41:04,215] Trial 53 finished with value: 2547.356282353692 and parameters: {'n_estimators': 691, 'max_depth': 15, 'num_leaves': 183, 'learning_rate': 0.23214733673061982, 'min_data_in_leaf': 31}. Best is trial 52 with value: 2514.374150394341.
# [I 2026-02-25 11:41:28,283] Trial 54 finished with value: 2545.3774533747596 and parameters: {'n_estimators': 641, 'max_depth': 14, 'num_leaves': 159, 'learning_rate': 0.13759655941057092, 'min_data_in_leaf': 19}. Best is trial 52 with value: 2514.374150394341.
# [I 2026-02-25 11:41:54,263] Trial 55 finished with value: 2885.382421644822 and parameters: {'n_estimators': 586, 'max_depth': 14, 'num_leaves': 192, 'learning_rate': 0.07381752987739343, 'min_data_in_leaf': 156}. Best is trial 52 with value: 2514.374150394341.
# [I 2026-02-25 11:42:10,825] Trial 56 finished with value: 2565.82358850681 and parameters: {'n_estimators': 621, 'max_depth': 15, 'num_leaves': 148, 'learning_rate': 0.19846607346469922, 'min_data_in_leaf': 32}. Best is trial 52 with value: 2514.374150394341.
# [I 2026-02-25 11:42:40,316] Trial 57 finished with value: 2699.917634451844 and parameters: {'n_estimators': 681, 'max_depth': 13, 'num_leaves': 170, 'learning_rate': 0.23490213118556885, 'min_data_in_leaf': 200}. Best is trial 52 with value: 2514.374150394341.
# [I 2026-02-25 11:42:57,225] Trial 58 finished with value: 2609.7850201451897 and parameters: {'n_estimators': 541, 'max_depth': 14, 'num_leaves': 177, 'learning_rate': 0.09509265169951543, 'min_data_in_leaf': 22}. Best is trial 52 with value: 2514.374150394341.
# [I 2026-02-25 11:43:15,842] Trial 59 finished with value: 2513.0926219561406 and parameters: {'n_estimators': 578, 'max_depth': 15, 'num_leaves': 211, 'learning_rate': 0.19296342426639776, 'min_data_in_leaf': 10}. Best is trial 59 with value: 2513.0926219561406.
# [I 2026-02-25 11:43:39,354] Trial 60 finished with value: 2505.140050425768 and parameters: {'n_estimators': 709, 'max_depth': 15, 'num_leaves': 206, 'learning_rate': 0.1377655907939032, 'min_data_in_leaf': 14}. Best is trial 60 with value: 2505.140050425768.
# [I 2026-02-25 11:44:06,605] Trial 61 finished with value: 2504.1376723390213 and parameters: {'n_estimators': 727, 'max_depth': 15, 'num_leaves': 210, 'learning_rate': 0.15191019959663843, 'min_data_in_leaf': 16}. Best is trial 61 with value: 2504.1376723390213.
# [I 2026-02-25 11:44:28,711] Trial 62 finished with value: 2499.410291483438 and parameters: {'n_estimators': 732, 'max_depth': 15, 'num_leaves': 208, 'learning_rate': 0.1516836024244182, 'min_data_in_leaf': 11}. Best is trial 62 with value: 2499.410291483438.
# [I 2026-02-25 11:44:52,160] Trial 63 finished with value: 2503.4274555439647 and parameters: {'n_estimators': 728, 'max_depth': 15, 'num_leaves': 196, 'learning_rate': 0.14648543415328918, 'min_data_in_leaf': 12}. Best is trial 62 with value: 2499.410291483438.
# [I 2026-02-25 11:45:20,763] Trial 64 finished with value: 2625.8076072734207 and parameters: {'n_estimators': 725, 'max_depth': 15, 'num_leaves': 197, 'learning_rate': 0.05126966064637453, 'min_data_in_leaf': 12}. Best is trial 62 with value: 2499.410291483438.
# [I 2026-02-25 11:45:47,895] Trial 65 finished with value: 2520.6752893411162 and parameters: {'n_estimators': 746, 'max_depth': 15, 'num_leaves': 221, 'learning_rate': 0.13351996536372931, 'min_data_in_leaf': 26}. Best is trial 62 with value: 2499.410291483438.
# [I 2026-02-25 11:46:15,341] Trial 66 finished with value: 2509.750293133226 and parameters: {'n_estimators': 768, 'max_depth': 15, 'num_leaves': 213, 'learning_rate': 0.09638729929423893, 'min_data_in_leaf': 10}. Best is trial 62 with value: 2499.410291483438.
# [I 2026-02-25 11:46:39,600] Trial 67 finished with value: 2530.015093619123 and parameters: {'n_estimators': 798, 'max_depth': 15, 'num_leaves': 190, 'learning_rate': 0.09150218446430936, 'min_data_in_leaf': 14}. Best is trial 62 with value: 2499.410291483438.
# [I 2026-02-25 11:47:10,381] Trial 68 finished with value: 2498.2707085417487 and parameters: {'n_estimators': 759, 'max_depth': 15, 'num_leaves': 214, 'learning_rate': 0.14219280225745812, 'min_data_in_leaf': 10}. Best is trial 68 with value: 2498.2707085417487.
# [I 2026-02-25 11:47:58,898] Trial 69 finished with value: 2496.746626719549 and parameters: {'n_estimators': 762, 'max_depth': 15, 'num_leaves': 241, 'learning_rate': 0.14019887038920997, 'min_data_in_leaf': 10}. Best is trial 69 with value: 2496.746626719549.
# [I 2026-02-25 11:48:32,359] Trial 70 finished with value: 2998.2369719788326 and parameters: {'n_estimators': 763, 'max_depth': 15, 'num_leaves': 248, 'learning_rate': 0.9945868303663463, 'min_data_in_leaf': 32}. Best is trial 69 with value: 2496.746626719549.
# [I 2026-02-25 11:48:56,423] Trial 71 finished with value: 2496.7559355356493 and parameters: {'n_estimators': 723, 'max_depth': 15, 'num_leaves': 215, 'learning_rate': 0.1350190284061391, 'min_data_in_leaf': 10}. Best is trial 69 with value: 2496.746626719549.
# [I 2026-02-25 11:49:21,506] Trial 72 finished with value: 2496.71819115053 and parameters: {'n_estimators': 716, 'max_depth': 15, 'num_leaves': 225, 'learning_rate': 0.14516136725316384, 'min_data_in_leaf': 10}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:49:48,619] Trial 73 finished with value: 2511.4672070753195 and parameters: {'n_estimators': 710, 'max_depth': 15, 'num_leaves': 260, 'learning_rate': 0.1405225545966088, 'min_data_in_leaf': 26}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:50:14,967] Trial 74 finished with value: 2513.0067189867623 and parameters: {'n_estimators': 667, 'max_depth': 15, 'num_leaves': 225, 'learning_rate': 0.11955774791679843, 'min_data_in_leaf': 15}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:50:46,136] Trial 75 finished with value: 2543.0597883222617 and parameters: {'n_estimators': 709, 'max_depth': 15, 'num_leaves': 241, 'learning_rate': 0.15243470924934965, 'min_data_in_leaf': 45}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:51:14,351] Trial 76 finished with value: 2602.6444115836557 and parameters: {'n_estimators': 748, 'max_depth': 15, 'num_leaves': 200, 'learning_rate': 0.07833888122778251, 'min_data_in_leaf': 33}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:51:51,316] Trial 77 finished with value: 2511.2551739427204 and parameters: {'n_estimators': 799, 'max_depth': 13, 'num_leaves': 221, 'learning_rate': 0.1470421436632439, 'min_data_in_leaf': 25}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:52:16,036] Trial 78 finished with value: 2840.717805934778 and parameters: {'n_estimators': 714, 'max_depth': 15, 'num_leaves': 237, 'learning_rate': 0.6781266218559299, 'min_data_in_leaf': 10}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:52:34,510] Trial 79 finished with value: 2680.3372787132334 and parameters: {'n_estimators': 749, 'max_depth': 15, 'num_leaves': 131, 'learning_rate': 0.5963201296424452, 'min_data_in_leaf': 26}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:53:03,454] Trial 80 finished with value: 2668.0159031234007 and parameters: {'n_estimators': 781, 'max_depth': 15, 'num_leaves': 228, 'learning_rate': 0.11719781925583209, 'min_data_in_leaf': 135}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:53:25,423] Trial 81 finished with value: 2537.530437518381 and parameters: {'n_estimators': 767, 'max_depth': 15, 'num_leaves': 216, 'learning_rate': 0.07577414100166456, 'min_data_in_leaf': 10}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:53:45,316] Trial 82 finished with value: 2515.9347437276338 and parameters: {'n_estimators': 691, 'max_depth': 15, 'num_leaves': 216, 'learning_rate': 0.11140354061800088, 'min_data_in_leaf': 15}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:54:08,591] Trial 83 finished with value: 2636.586651585183 and parameters: {'n_estimators': 732, 'max_depth': 14, 'num_leaves': 195, 'learning_rate': 0.1515945945402276, 'min_data_in_leaf': 105}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:54:25,348] Trial 84 finished with value: 2521.828118025254 and parameters: {'n_estimators': 670, 'max_depth': 15, 'num_leaves': 201, 'learning_rate': 0.21531453090058095, 'min_data_in_leaf': 16}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:54:50,182] Trial 85 finished with value: 2547.3601321265514 and parameters: {'n_estimators': 762, 'max_depth': 14, 'num_leaves': 228, 'learning_rate': 0.24608171456275718, 'min_data_in_leaf': 35}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:55:12,580] Trial 86 finished with value: 2557.2218305979536 and parameters: {'n_estimators': 783, 'max_depth': 15, 'num_leaves': 253, 'learning_rate': 0.28618972464417974, 'min_data_in_leaf': 23}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:55:31,684] Trial 87 finished with value: 2538.8582699963486 and parameters: {'n_estimators': 699, 'max_depth': 15, 'num_leaves': 204, 'learning_rate': 0.08455002418119198, 'min_data_in_leaf': 10}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:55:59,920] Trial 88 finished with value: 2922.999990624659 and parameters: {'n_estimators': 732, 'max_depth': 14, 'num_leaves': 246, 'learning_rate': 0.05418431213605536, 'min_data_in_leaf': 181}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:56:17,894] Trial 89 finished with value: 2502.057107383566 and parameters: {'n_estimators': 653, 'max_depth': 15, 'num_leaves': 235, 'learning_rate': 0.16896345870531898, 'min_data_in_leaf': 14}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:56:31,047] Trial 90 finished with value: 2938.3854519564957 and parameters: {'n_estimators': 657, 'max_depth': 6, 'num_leaves': 236, 'learning_rate': 0.16323300118705236, 'min_data_in_leaf': 28}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:56:50,458] Trial 91 finished with value: 2508.681408832181 and parameters: {'n_estimators': 716, 'max_depth': 15, 'num_leaves': 213, 'learning_rate': 0.11457533393979194, 'min_data_in_leaf': 14}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:57:13,682] Trial 92 finished with value: 2504.564562299183 and parameters: {'n_estimators': 722, 'max_depth': 15, 'num_leaves': 220, 'learning_rate': 0.12213528499434013, 'min_data_in_leaf': 16}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:57:34,698] Trial 93 finished with value: 2514.620132247493 and parameters: {'n_estimators': 745, 'max_depth': 13, 'num_leaves': 222, 'learning_rate': 0.20470701481094922, 'min_data_in_leaf': 22}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:57:54,134] Trial 94 finished with value: 2502.5101363950594 and parameters: {'n_estimators': 679, 'max_depth': 15, 'num_leaves': 230, 'learning_rate': 0.16510804029430082, 'min_data_in_leaf': 16}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:58:13,659] Trial 95 finished with value: 2502.4574169189245 and parameters: {'n_estimators': 681, 'max_depth': 14, 'num_leaves': 240, 'learning_rate': 0.1686794161094175, 'min_data_in_leaf': 17}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:58:33,596] Trial 96 finished with value: 2509.6932536515333 and parameters: {'n_estimators': 643, 'max_depth': 14, 'num_leaves': 253, 'learning_rate': 0.17046700913790666, 'min_data_in_leaf': 21}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:58:54,280] Trial 97 finished with value: 2526.6373379402166 and parameters: {'n_estimators': 679, 'max_depth': 14, 'num_leaves': 240, 'learning_rate': 0.15958572405021743, 'min_data_in_leaf': 30}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:59:13,836] Trial 98 finished with value: 2879.0858990100273 and parameters: {'n_estimators': 695, 'max_depth': 14, 'num_leaves': 232, 'learning_rate': 0.8209641611572469, 'min_data_in_leaf': 23}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:59:23,470] Trial 99 finished with value: 2734.722448014185 and parameters: {'n_estimators': 743, 'max_depth': 15, 'num_leaves': 36, 'learning_rate': 0.25650661542707187, 'min_data_in_leaf': 35}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 11:59:40,743] Trial 100 finished with value: 2845.778484191102 and parameters: {'n_estimators': 679, 'max_depth': 15, 'num_leaves': 227, 'learning_rate': 0.7359184879308754, 'min_data_in_leaf': 17}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 12:00:02,108] Trial 101 finished with value: 2502.138563571568 and parameters: {'n_estimators': 726, 'max_depth': 15, 'num_leaves': 245, 'learning_rate': 0.12452217649141278, 'min_data_in_leaf': 16}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 12:00:27,118] Trial 102 finished with value: 2500.4488001857176 and parameters: {'n_estimators': 756, 'max_depth': 15, 'num_leaves': 247, 'learning_rate': 0.18138085678284602, 'min_data_in_leaf': 14}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 12:01:01,352] Trial 103 finished with value: 2519.902948792302 and parameters: {'n_estimators': 788, 'max_depth': 15, 'num_leaves': 245, 'learning_rate': 0.21311589496839373, 'min_data_in_leaf': 21}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 12:01:29,184] Trial 104 finished with value: 2541.063295443936 and parameters: {'n_estimators': 757, 'max_depth': 14, 'num_leaves': 255, 'learning_rate': 0.18385092985469928, 'min_data_in_leaf': 42}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 12:01:54,690] Trial 105 finished with value: 2520.4850432259673 and parameters: {'n_estimators': 775, 'max_depth': 15, 'num_leaves': 237, 'learning_rate': 0.1932728980497072, 'min_data_in_leaf': 28}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 12:02:15,990] Trial 106 finished with value: 2500.617319264868 and parameters: {'n_estimators': 700, 'max_depth': 15, 'num_leaves': 249, 'learning_rate': 0.10282686554375053, 'min_data_in_leaf': 13}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 12:02:37,433] Trial 107 finished with value: 2562.8279746142334 and parameters: {'n_estimators': 663, 'max_depth': 14, 'num_leaves': 249, 'learning_rate': 0.06601235408750346, 'min_data_in_leaf': 14}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 12:02:59,653] Trial 108 finished with value: 2515.175385397881 and parameters: {'n_estimators': 701, 'max_depth': 15, 'num_leaves': 260, 'learning_rate': 0.09964308187295394, 'min_data_in_leaf': 20}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 12:03:17,717] Trial 109 finished with value: 2534.66894962789 and parameters: {'n_estimators': 646, 'max_depth': 14, 'num_leaves': 232, 'learning_rate': 0.24611117563080934, 'min_data_in_leaf': 25}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 12:03:36,067] Trial 110 finished with value: 2517.1928641051763 and parameters: {'n_estimators': 607, 'max_depth': 15, 'num_leaves': 242, 'learning_rate': 0.13300634986235035, 'min_data_in_leaf': 19}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 12:03:57,397] Trial 111 finished with value: 2499.256990875204 and parameters: {'n_estimators': 733, 'max_depth': 15, 'num_leaves': 251, 'learning_rate': 0.17340833249215828, 'min_data_in_leaf': 13}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 12:04:17,613] Trial 112 finished with value: 2500.7017546678226 and parameters: {'n_estimators': 683, 'max_depth': 15, 'num_leaves': 249, 'learning_rate': 0.17638849488156244, 'min_data_in_leaf': 10}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 12:04:40,146] Trial 113 finished with value: 2501.8090550621773 and parameters: {'n_estimators': 735, 'max_depth': 15, 'num_leaves': 254, 'learning_rate': 0.17433788671756473, 'min_data_in_leaf': 10}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 12:05:02,241] Trial 114 finished with value: 2523.043554179779 and parameters: {'n_estimators': 752, 'max_depth': 15, 'num_leaves': 255, 'learning_rate': 0.22314584752845776, 'min_data_in_leaf': 10}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 12:05:25,074] Trial 115 finished with value: 2498.593995993929 and parameters: {'n_estimators': 735, 'max_depth': 15, 'num_leaves': 252, 'learning_rate': 0.11781394160371181, 'min_data_in_leaf': 13}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 12:05:46,755] Trial 116 finished with value: 2502.6511251403326 and parameters: {'n_estimators': 771, 'max_depth': 15, 'num_leaves': 249, 'learning_rate': 0.18483857584009974, 'min_data_in_leaf': 10}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 12:06:10,238] Trial 117 finished with value: 2519.5756300183734 and parameters: {'n_estimators': 735, 'max_depth': 15, 'num_leaves': 256, 'learning_rate': 0.08676640803504374, 'min_data_in_leaf': 13}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 12:06:35,501] Trial 118 finished with value: 2514.0953645753016 and parameters: {'n_estimators': 788, 'max_depth': 15, 'num_leaves': 260, 'learning_rate': 0.10795110004312697, 'min_data_in_leaf': 25}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 12:06:57,891] Trial 119 finished with value: 2498.968608429946 and parameters: {'n_estimators': 713, 'max_depth': 14, 'num_leaves': 252, 'learning_rate': 0.14640028609677347, 'min_data_in_leaf': 13}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 12:07:24,117] Trial 120 finished with value: 2514.8194512315827 and parameters: {'n_estimators': 709, 'max_depth': 14, 'num_leaves': 251, 'learning_rate': 0.20802717923353564, 'min_data_in_leaf': 20}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 12:07:46,219] Trial 121 finished with value: 2499.9464195006753 and parameters: {'n_estimators': 738, 'max_depth': 15, 'num_leaves': 236, 'learning_rate': 0.14962864013796626, 'min_data_in_leaf': 13}. Best is trial 72 with value: 2496.71819115053.
# [I 2026-02-25 12:08:06,566] Trial 122 finished with value: 2495.396214934132 and parameters: {'n_estimators': 741, 'max_depth': 15, 'num_leaves': 245, 'learning_rate': 0.13766140502974605, 'min_data_in_leaf': 10}. Best is trial 122 with value: 2495.396214934132.
# [I 2026-02-25 12:08:29,085] Trial 123 finished with value: 2494.345662867176 and parameters: {'n_estimators': 763, 'max_depth': 15, 'num_leaves': 245, 'learning_rate': 0.1429380286563595, 'min_data_in_leaf': 13}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:08:52,043] Trial 124 finished with value: 2510.5895706458236 and parameters: {'n_estimators': 761, 'max_depth': 15, 'num_leaves': 242, 'learning_rate': 0.13781585749378197, 'min_data_in_leaf': 23}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:09:12,209] Trial 125 finished with value: 2683.3956090189527 and parameters: {'n_estimators': 756, 'max_depth': 14, 'num_leaves': 238, 'learning_rate': 0.495330906977699, 'min_data_in_leaf': 18}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:09:37,804] Trial 126 finished with value: 2529.7984747316214 and parameters: {'n_estimators': 800, 'max_depth': 15, 'num_leaves': 246, 'learning_rate': 0.10003786281337065, 'min_data_in_leaf': 28}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:09:59,729] Trial 127 finished with value: 2541.61396029327 and parameters: {'n_estimators': 743, 'max_depth': 15, 'num_leaves': 227, 'learning_rate': 0.07318426213444912, 'min_data_in_leaf': 14}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:10:14,012] Trial 128 finished with value: 2591.685425850941 and parameters: {'n_estimators': 779, 'max_depth': 14, 'num_leaves': 92, 'learning_rate': 0.12210615379431322, 'min_data_in_leaf': 13}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:10:34,340] Trial 129 finished with value: 2510.2877357672887 and parameters: {'n_estimators': 711, 'max_depth': 15, 'num_leaves': 235, 'learning_rate': 0.13170714525969926, 'min_data_in_leaf': 20}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:10:42,565] Trial 130 finished with value: 2648.6194490099087 and parameters: {'n_estimators': 221, 'max_depth': 15, 'num_leaves': 243, 'learning_rate': 0.14382868694095702, 'min_data_in_leaf': 23}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:11:05,510] Trial 131 finished with value: 2495.6102221666883 and parameters: {'n_estimators': 719, 'max_depth': 15, 'num_leaves': 250, 'learning_rate': 0.1502608985591372, 'min_data_in_leaf': 10}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:11:26,510] Trial 132 finished with value: 3012.6958256345433 and parameters: {'n_estimators': 720, 'max_depth': 15, 'num_leaves': 249, 'learning_rate': 0.8839728845482102, 'min_data_in_leaf': 14}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:11:56,401] Trial 133 finished with value: 2653.348875736254 and parameters: {'n_estimators': 741, 'max_depth': 15, 'num_leaves': 256, 'learning_rate': 0.15070517174254483, 'min_data_in_leaf': 156}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:12:22,763] Trial 134 finished with value: 2510.786504210815 and parameters: {'n_estimators': 763, 'max_depth': 15, 'num_leaves': 239, 'learning_rate': 0.10249848203256667, 'min_data_in_leaf': 18}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:12:41,463] Trial 135 finished with value: 2505.637176725881 and parameters: {'n_estimators': 700, 'max_depth': 15, 'num_leaves': 225, 'learning_rate': 0.1176381759339779, 'min_data_in_leaf': 10}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:12:50,569] Trial 136 finished with value: 2552.890169102402 and parameters: {'n_estimators': 303, 'max_depth': 14, 'num_leaves': 233, 'learning_rate': 0.19681734822246288, 'min_data_in_leaf': 15}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:13:16,783] Trial 137 finished with value: 2642.3600825764474 and parameters: {'n_estimators': 721, 'max_depth': 15, 'num_leaves': 246, 'learning_rate': 0.08117234796640832, 'min_data_in_leaf': 74}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:13:24,320] Trial 138 finished with value: 3812.0633503133586 and parameters: {'n_estimators': 752, 'max_depth': 14, 'num_leaves': 7, 'learning_rate': 0.15261122709136893, 'min_data_in_leaf': 29}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:13:50,797] Trial 139 finished with value: 2558.961774073163 and parameters: {'n_estimators': 780, 'max_depth': 15, 'num_leaves': 252, 'learning_rate': 0.059330914274903654, 'min_data_in_leaf': 18}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:14:10,699] Trial 140 finished with value: 2509.2952073468327 and parameters: {'n_estimators': 733, 'max_depth': 15, 'num_leaves': 218, 'learning_rate': 0.11459791447194584, 'min_data_in_leaf': 13}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:14:30,964] Trial 141 finished with value: 2499.7041674485517 and parameters: {'n_estimators': 698, 'max_depth': 15, 'num_leaves': 260, 'learning_rate': 0.18377812568306276, 'min_data_in_leaf': 10}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:14:53,401] Trial 142 finished with value: 2496.787376150455 and parameters: {'n_estimators': 701, 'max_depth': 15, 'num_leaves': 258, 'learning_rate': 0.15719311888124154, 'min_data_in_leaf': 10}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:15:19,799] Trial 143 finished with value: 2525.032704214426 and parameters: {'n_estimators': 718, 'max_depth': 15, 'num_leaves': 257, 'learning_rate': 0.22986743225218462, 'min_data_in_leaf': 10}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:15:43,879] Trial 144 finished with value: 2555.8814462125574 and parameters: {'n_estimators': 767, 'max_depth': 8, 'num_leaves': 260, 'learning_rate': 0.1561686960195844, 'min_data_in_leaf': 17}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:16:06,808] Trial 145 finished with value: 2517.4365115512664 and parameters: {'n_estimators': 740, 'max_depth': 15, 'num_leaves': 243, 'learning_rate': 0.19193020591461754, 'min_data_in_leaf': 23}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:16:18,774] Trial 146 finished with value: 3287.1093521879047 and parameters: {'n_estimators': 751, 'max_depth': 5, 'num_leaves': 252, 'learning_rate': 0.13521078534838807, 'min_data_in_leaf': 20}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:16:39,692] Trial 147 finished with value: 2510.2643325298377 and parameters: {'n_estimators': 710, 'max_depth': 15, 'num_leaves': 238, 'learning_rate': 0.20849675851954985, 'min_data_in_leaf': 14}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:17:07,819] Trial 148 finished with value: 2594.7673168500314 and parameters: {'n_estimators': 691, 'max_depth': 14, 'num_leaves': 260, 'learning_rate': 0.16087388927765878, 'min_data_in_leaf': 91}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:17:28,369] Trial 149 finished with value: 2499.283829958961 and parameters: {'n_estimators': 732, 'max_depth': 15, 'num_leaves': 230, 'learning_rate': 0.17713259722054683, 'min_data_in_leaf': 10}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:17:39,216] Trial 150 finished with value: 2551.5664310755915 and parameters: {'n_estimators': 374, 'max_depth': 15, 'num_leaves': 224, 'learning_rate': 0.13861722868130982, 'min_data_in_leaf': 10}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:17:58,738] Trial 151 finished with value: 2507.2747353993313 and parameters: {'n_estimators': 726, 'max_depth': 15, 'num_leaves': 231, 'learning_rate': 0.185232554947946, 'min_data_in_leaf': 17}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:18:04,253] Trial 152 finished with value: 2661.332432725638 and parameters: {'n_estimators': 158, 'max_depth': 15, 'num_leaves': 246, 'learning_rate': 0.17269708562741595, 'min_data_in_leaf': 14}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:18:24,944] Trial 153 finished with value: 2494.8845370428676 and parameters: {'n_estimators': 738, 'max_depth': 15, 'num_leaves': 254, 'learning_rate': 0.15581928846996693, 'min_data_in_leaf': 10}. Best is trial 123 with value: 2494.345662867176.
# [I 2026-02-25 12:18:48,083] Trial 154 finished with value: 2490.8422981964623 and parameters: {'n_estimators': 738, 'max_depth': 15, 'num_leaves': 253, 'learning_rate': 0.12741494141527826, 'min_data_in_leaf': 10}. Best is trial 154 with value: 2490.8422981964623.
# [I 2026-02-25 12:19:04,589] Trial 155 finished with value: 2689.1350181400076 and parameters: {'n_estimators': 720, 'max_depth': 7, 'num_leaves': 254, 'learning_rate': 0.1259255720062337, 'min_data_in_leaf': 10}. Best is trial 154 with value: 2490.8422981964623.
# [I 2026-02-25 12:19:25,442] Trial 156 finished with value: 2531.563114200956 and parameters: {'n_estimators': 705, 'max_depth': 15, 'num_leaves': 252, 'learning_rate': 0.08894484733064051, 'min_data_in_leaf': 20}. Best is trial 154 with value: 2490.8422981964623.
# [I 2026-02-25 12:19:46,187] Trial 157 finished with value: 2498.182789946752 and parameters: {'n_estimators': 770, 'max_depth': 15, 'num_leaves': 241, 'learning_rate': 0.15803764296741485, 'min_data_in_leaf': 10}. Best is trial 154 with value: 2490.8422981964623.
# [I 2026-02-25 12:20:08,910] Trial 158 finished with value: 2499.9951226714174 and parameters: {'n_estimators': 791, 'max_depth': 14, 'num_leaves': 242, 'learning_rate': 0.12026774091163395, 'min_data_in_leaf': 17}. Best is trial 154 with value: 2490.8422981964623.
# [I 2026-02-25 12:20:30,878] Trial 159 finished with value: 2514.226241293995 and parameters: {'n_estimators': 772, 'max_depth': 15, 'num_leaves': 231, 'learning_rate': 0.15819214175292912, 'min_data_in_leaf': 24}. Best is trial 154 with value: 2490.8422981964623.
# [I 2026-02-25 12:20:57,668] Trial 160 finished with value: 2617.3645709596626 and parameters: {'n_estimators': 769, 'max_depth': 15, 'num_leaves': 241, 'learning_rate': 0.13498478072739087, 'min_data_in_leaf': 104}. Best is trial 154 with value: 2490.8422981964623.
# [I 2026-02-25 12:21:18,385] Trial 161 finished with value: 2496.5184689278944 and parameters: {'n_estimators': 736, 'max_depth': 15, 'num_leaves': 256, 'learning_rate': 0.16707748089302418, 'min_data_in_leaf': 13}. Best is trial 154 with value: 2490.8422981964623.
# [I 2026-02-25 12:21:41,481] Trial 162 finished with value: 2497.2333858035868 and parameters: {'n_estimators': 751, 'max_depth': 15, 'num_leaves': 250, 'learning_rate': 0.1620383259015003, 'min_data_in_leaf': 16}. Best is trial 154 with value: 2490.8422981964623.
# [I 2026-02-25 12:22:05,041] Trial 163 finished with value: 2511.8789693851368 and parameters: {'n_estimators': 750, 'max_depth': 15, 'num_leaves': 247, 'learning_rate': 0.20500103035520598, 'min_data_in_leaf': 16}. Best is trial 154 with value: 2490.8422981964623.
# [I 2026-02-25 12:22:26,114] Trial 164 finished with value: 2506.9089342254106 and parameters: {'n_estimators': 741, 'max_depth': 15, 'num_leaves': 252, 'learning_rate': 0.17128504409347445, 'min_data_in_leaf': 20}. Best is trial 154 with value: 2490.8422981964623.
# [I 2026-02-25 12:22:49,559] Trial 165 finished with value: 2494.0736788815675 and parameters: {'n_estimators': 779, 'max_depth': 15, 'num_leaves': 256, 'learning_rate': 0.10726660798984534, 'min_data_in_leaf': 10}. Best is trial 154 with value: 2490.8422981964623.
# [I 2026-02-25 12:23:11,357] Trial 166 finished with value: 2646.481588748065 and parameters: {'n_estimators': 782, 'max_depth': 15, 'num_leaves': 256, 'learning_rate': 0.41562346063939964, 'min_data_in_leaf': 14}. Best is trial 154 with value: 2490.8422981964623.
# [I 2026-02-25 12:23:32,890] Trial 167 finished with value: 2501.730507369991 and parameters: {'n_estimators': 761, 'max_depth': 14, 'num_leaves': 251, 'learning_rate': 0.10794752698889162, 'min_data_in_leaf': 17}. Best is trial 154 with value: 2490.8422981964623.
# [I 2026-02-25 12:23:59,596] Trial 168 finished with value: 2518.227198339985 and parameters: {'n_estimators': 793, 'max_depth': 15, 'num_leaves': 256, 'learning_rate': 0.09216032224769094, 'min_data_in_leaf': 22}. Best is trial 154 with value: 2490.8422981964623.
# [I 2026-02-25 12:24:21,396] Trial 169 finished with value: 2496.498610597471 and parameters: {'n_estimators': 773, 'max_depth': 15, 'num_leaves': 246, 'learning_rate': 0.14112100971239325, 'min_data_in_leaf': 13}. Best is trial 154 with value: 2490.8422981964623.
# [I 2026-02-25 12:24:43,229] Trial 170 finished with value: 2520.2888953387596 and parameters: {'n_estimators': 777, 'max_depth': 15, 'num_leaves': 245, 'learning_rate': 0.12763531188408717, 'min_data_in_leaf': 26}. Best is trial 154 with value: 2490.8422981964623.
# [I 2026-02-25 12:25:05,525] Trial 171 finished with value: 2498.8740263047134 and parameters: {'n_estimators': 760, 'max_depth': 15, 'num_leaves': 250, 'learning_rate': 0.14710795658743503, 'min_data_in_leaf': 14}. Best is trial 154 with value: 2490.8422981964623.
# [I 2026-02-25 12:25:28,761] Trial 172 finished with value: 2497.635094563655 and parameters: {'n_estimators': 758, 'max_depth': 15, 'num_leaves': 247, 'learning_rate': 0.144615049653931, 'min_data_in_leaf': 16}. Best is trial 154 with value: 2490.8422981964623.
# [I 2026-02-25 12:25:50,852] Trial 173 finished with value: 2505.0989714454095 and parameters: {'n_estimators': 756, 'max_depth': 15, 'num_leaves': 241, 'learning_rate': 0.11277104523348491, 'min_data_in_leaf': 17}. Best is trial 154 with value: 2490.8422981964623.
# [I 2026-02-25 12:26:20,978] Trial 174 finished with value: 2621.7105522267907 and parameters: {'n_estimators': 771, 'max_depth': 15, 'num_leaves': 260, 'learning_rate': 0.1471637827854867, 'min_data_in_leaf': 123}. Best is trial 154 with value: 2490.8422981964623.
# [I 2026-02-25 12:26:43,433] Trial 175 finished with value: 2489.4826879346365 and parameters: {'n_estimators': 755, 'max_depth': 15, 'num_leaves': 247, 'learning_rate': 0.13186295136144752, 'min_data_in_leaf': 10}. Best is trial 175 with value: 2489.4826879346365.
# [I 2026-02-25 12:27:08,626] Trial 176 finished with value: 2528.803687820771 and parameters: {'n_estimators': 789, 'max_depth': 15, 'num_leaves': 246, 'learning_rate': 0.06942567662012952, 'min_data_in_leaf': 10}. Best is trial 175 with value: 2489.4826879346365.
# [I 2026-02-25 12:27:30,927] Trial 177 finished with value: 2523.264738417044 and parameters: {'n_estimators': 746, 'max_depth': 15, 'num_leaves': 237, 'learning_rate': 0.0907140008243865, 'min_data_in_leaf': 19}. Best is trial 175 with value: 2489.4826879346365.
# [I 2026-02-25 12:27:52,830] Trial 178 finished with value: 2495.5218945994234 and parameters: {'n_estimators': 777, 'max_depth': 15, 'num_leaves': 244, 'learning_rate': 0.12600767974763452, 'min_data_in_leaf': 10}. Best is trial 175 with value: 2489.4826879346365.
# [I 2026-02-25 12:28:14,386] Trial 179 finished with value: 2491.7122094768215 and parameters: {'n_estimators': 775, 'max_depth': 15, 'num_leaves': 241, 'learning_rate': 0.1309446077137957, 'min_data_in_leaf': 10}. Best is trial 175 with value: 2489.4826879346365.
# [I 2026-02-25 12:28:36,980] Trial 180 finished with value: 2491.4572212002895 and parameters: {'n_estimators': 800, 'max_depth': 15, 'num_leaves': 241, 'learning_rate': 0.12589687242869121, 'min_data_in_leaf': 10}. Best is trial 175 with value: 2489.4826879346365.
# [I 2026-02-25 12:29:02,272] Trial 181 finished with value: 2496.671104406504 and parameters: {'n_estimators': 800, 'max_depth': 15, 'num_leaves': 243, 'learning_rate': 0.1322798396117047, 'min_data_in_leaf': 10}. Best is trial 175 with value: 2489.4826879346365.
# [I 2026-02-25 12:29:26,948] Trial 182 finished with value: 2494.0503066854194 and parameters: {'n_estimators': 800, 'max_depth': 15, 'num_leaves': 246, 'learning_rate': 0.1272223658482865, 'min_data_in_leaf': 16}. Best is trial 175 with value: 2489.4826879346365.
# [I 2026-02-25 12:29:53,582] Trial 183 finished with value: 2495.2977313616975 and parameters: {'n_estimators': 796, 'max_depth': 15, 'num_leaves': 237, 'learning_rate': 0.1057067598896848, 'min_data_in_leaf': 10}. Best is trial 175 with value: 2489.4826879346365.
# [I 2026-02-25 12:30:19,256] Trial 184 finished with value: 2496.5101212229492 and parameters: {'n_estimators': 796, 'max_depth': 15, 'num_leaves': 236, 'learning_rate': 0.10975820958966616, 'min_data_in_leaf': 10}. Best is trial 175 with value: 2489.4826879346365.
# [I 2026-02-25 12:30:41,889] Trial 185 finished with value: 2496.4720671057366 and parameters: {'n_estimators': 799, 'max_depth': 15, 'num_leaves': 236, 'learning_rate': 0.10673233776911534, 'min_data_in_leaf': 13}. Best is trial 175 with value: 2489.4826879346365.
# [I 2026-02-25 12:31:05,521] Trial 186 finished with value: 2521.8919776228113 and parameters: {'n_estimators': 797, 'max_depth': 15, 'num_leaves': 234, 'learning_rate': 0.07738077449271942, 'min_data_in_leaf': 14}. Best is trial 175 with value: 2489.4826879346365.
# [I 2026-02-25 12:31:28,242] Trial 187 finished with value: 2510.1809170065007 and parameters: {'n_estimators': 800, 'max_depth': 15, 'num_leaves': 238, 'learning_rate': 0.10412880453418366, 'min_data_in_leaf': 20}. Best is trial 175 with value: 2489.4826879346365.
# [I 2026-02-25 12:31:53,468] Trial 188 finished with value: 2501.5254891022983 and parameters: {'n_estimators': 785, 'max_depth': 15, 'num_leaves': 243, 'learning_rate': 0.09901379931514936, 'min_data_in_leaf': 13}. Best is trial 175 with value: 2489.4826879346365.
# [I 2026-02-25 12:32:17,729] Trial 189 finished with value: 2498.696845903619 and parameters: {'n_estimators': 797, 'max_depth': 15, 'num_leaves': 235, 'learning_rate': 0.12063500472687731, 'min_data_in_leaf': 17}. Best is trial 175 with value: 2489.4826879346365.
# [I 2026-02-25 12:32:46,601] Trial 190 finished with value: 2592.1360668240904 and parameters: {'n_estimators': 778, 'max_depth': 15, 'num_leaves': 239, 'learning_rate': 0.05534082473475922, 'min_data_in_leaf': 23}. Best is trial 175 with value: 2489.4826879346365.
# [I 2026-02-25 12:33:10,813] Trial 191 finished with value: 2495.187508355613 and parameters: {'n_estimators': 784, 'max_depth': 15, 'num_leaves': 228, 'learning_rate': 0.12216418533450317, 'min_data_in_leaf': 10}. Best is trial 175 with value: 2489.4826879346365.
# [I 2026-02-25 12:33:37,730] Trial 192 finished with value: 2489.336126952272 and parameters: {'n_estimators': 800, 'max_depth': 15, 'num_leaves': 244, 'learning_rate': 0.12429092072713381, 'min_data_in_leaf': 10}. Best is trial 192 with value: 2489.336126952272.
# [I 2026-02-25 12:34:02,779] Trial 193 finished with value: 2498.7179138499964 and parameters: {'n_estimators': 799, 'max_depth': 15, 'num_leaves': 244, 'learning_rate': 0.08805074452570288, 'min_data_in_leaf': 10}. Best is trial 192 with value: 2489.336126952272.
# [I 2026-02-25 12:34:14,232] Trial 194 finished with value: 2676.4357406538616 and parameters: {'n_estimators': 785, 'max_depth': 15, 'num_leaves': 63, 'learning_rate': 0.11755871004955921, 'min_data_in_leaf': 14}. Best is trial 192 with value: 2489.336126952272.
# [I 2026-02-25 12:34:36,367] Trial 195 finished with value: 2499.375242499306 and parameters: {'n_estimators': 782, 'max_depth': 15, 'num_leaves': 234, 'learning_rate': 0.10424970756931656, 'min_data_in_leaf': 13}. Best is trial 192 with value: 2489.336126952272.
# [I 2026-02-25 12:34:58,265] Trial 196 finished with value: 2501.5742035012704 and parameters: {'n_estimators': 798, 'max_depth': 15, 'num_leaves': 230, 'learning_rate': 0.12435000135381308, 'min_data_in_leaf': 18}. Best is trial 192 with value: 2489.336126952272.
# [I 2026-02-25 12:35:14,157] Trial 197 finished with value: 2605.1725770532908 and parameters: {'n_estimators': 780, 'max_depth': 15, 'num_leaves': 128, 'learning_rate': 0.0792768356383188, 'min_data_in_leaf': 10}. Best is trial 192 with value: 2489.336126952272.
# [I 2026-02-25 12:35:36,943] Trial 198 finished with value: 2500.3774192648393 and parameters: {'n_estimators': 785, 'max_depth': 15, 'num_leaves': 245, 'learning_rate': 0.10657552207281888, 'min_data_in_leaf': 15}. Best is trial 192 with value: 2489.336126952272.
# [I 2026-02-25 12:35:59,639] Trial 199 finished with value: 2503.7787654020876 and parameters: {'n_estimators': 800, 'max_depth': 15, 'num_leaves': 238, 'learning_rate': 0.13133513460870522, 'min_data_in_leaf': 20}. Best is trial 192 with value: 2489.336126952272.

# %%
optuna.visualization.plot_param_importances(study)

# %%
study.best_value
# Out:
# 2489.336126952272

# %%
best_params = study.best_params
best_params
# Out:
# {'n_estimators': 800,
#  'max_depth': 15,
#  'num_leaves': 244,
#  'learning_rate': 0.12429092072713381,
#  'min_data_in_leaf': 10}

# %%
best_model = LGBMRegressor(**best_params, random_state= 42, verbose = -1)

# %%
best_model.fit(X_train, y_train)
# Out:
# LGBMRegressor(learning_rate=0.12429092072713381, max_depth=15,
#               min_data_in_leaf=10, n_estimators=800, num_leaves=244,
#               random_state=42, verbose=-1)

# %%
y_pred = best_model.predict(X_test)
print("RMSE:", root_mean_squared_error(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
print("R2:", r2_score(y_test, y_pred))
# Out:
# RMSE: 2383.622356575259
# MAE: 1159.5781742091317
# R2: 0.9889955019964942

# %%
plot_predictions_vs_actual(y_test, y_pred)

# %% [markdown]
# Guardo el modelo:

# %%
joblib.dump(best_model, "lgbm_best_model.joblib")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 joblib.dump(best_model, "lgbm_best_model.joblib")
#
# NameError: name 'best_model' is not defined

# %%
modelo = joblib.load("lgbm_best_model.joblib")

# %%
mask_econ = X_train["class"] == 0
mask_bus = X_train["class"] == 1

y_pred = modelo.predict(X_train)
print("RMSE:", root_mean_squared_error(y_train[mask_econ], y_pred[mask_econ]))
print("MAE:", mean_absolute_error(y_train[mask_econ], y_pred[mask_econ]))
print("R2:", r2_score(y_train[mask_econ], y_pred[mask_econ]))
# Out:
# RMSE: 959.1090496130238
# MAE: 566.6575441512105
# R2: 0.9341490400599268

# %%
mask_econ = X_test["class"] == 0
mask_bus = X_test["class"] == 1

y_pred = modelo.predict(X_test)
print("RMSE:", root_mean_squared_error(y_test[mask_econ], y_pred[mask_econ]))
print("MAE:", mean_absolute_error(y_test[mask_econ], y_pred[mask_econ]))
print("R2:", r2_score(y_test[mask_econ], y_pred[mask_econ]))
# Out:
# RMSE: 1356.152713175391
# MAE: 742.760479832018
# R2: 0.8721959274156338

# %%
y_pred = modelo.predict(X_train)
print("RMSE:", root_mean_squared_error(y_train[mask_bus], y_pred[mask_bus]))
print("MAE:", mean_absolute_error(y_train[mask_bus], y_pred[mask_bus]))
print("R2:", r2_score(y_train[mask_bus], y_pred[mask_bus]))
# Out:
# RMSE: 2479.548388278923
# MAE: 1392.205745365122
# R2: 0.9632240447022992

# %%
# Business
print("RMSE:", root_mean_squared_error(y_test[mask_bus], y_pred[mask_bus]))
print("MAE:", mean_absolute_error(y_test[mask_bus], y_pred[mask_bus]))
print("R2:", r2_score(y_test[mask_bus], y_pred[mask_bus]))
# Out:
# RMSE: 3765.853034519489
# MAE: 2081.619233263196
# R2: 0.9153923021076397

# %% [markdown]
# ----

# %%
train_set_eco, test_set_eco = train_test_split(df_eco, test_size= 0.2, random_state= 42)

# %%
ord_encoder = OrdinalEncoder(categories= [["economy", "business"]])
train_set_eco["class"] = ord_encoder.fit_transform(train_set_eco[["class"]])
test_set_eco["class"] = ord_encoder.transform(test_set_eco[["class"]])
OH_encoder = OneHotEncoder(handle_unknown="ignore", sparse_output=False)

cat_cols = [col for col in features_cat_reg if col != "class"]

train_encod = OH_encoder.fit_transform(train_set_eco[cat_cols])
test_encod = OH_encoder.transform(test_set_eco[cat_cols])

# Convertimos a DataFrame con nombres de columna
col_names = OH_encoder.get_feature_names_out(cat_cols)
train_encod_df = pd.DataFrame(train_encod, columns = col_names, index = train_set_eco.index)
test_encod_df = pd.DataFrame(test_encod, columns = col_names, index = test_set_eco.index)
resto_cols = [col for col in features if col not in cat_cols]
resto_cols
train_set_eco = pd.concat([train_set_eco[resto_cols + [target_reg]], train_encod_df], axis = 1)
test_set_eco = pd.concat([test_set_eco[resto_cols + [target_reg]], test_encod_df], axis = 1)

# %%
X_train_eco = train_set_eco.drop(columns=target_reg, axis = 1)
X_test_eco = test_set_eco.drop(columns = target_reg, axis = 1)

y_train_eco = train_set_eco[target_reg]
y_test_eco = test_set_eco[target_reg]

# %%
train_set_bus, test_set_bus = train_test_split(df_bus, test_size= 0.2, random_state= 42)

# %%
X_train_bus= train_set_bus.drop(columns=target_reg, axis = 1)
X_test_bus = test_set_bus.drop(columns = target_reg, axis = 1)

y_train_bus = train_set_bus[target_reg]
y_test_bus = test_set_bus[target_reg]

# %%
ord_encoder = OrdinalEncoder(categories= [["economy", "business"]])
train_set_bus["class"] = ord_encoder.fit_transform(train_set_bus[["class"]])
test_set_bus["class"] = ord_encoder.transform(test_set_bus[["class"]])
OH_encoder = OneHotEncoder(handle_unknown="ignore", sparse_output=False)

cat_cols = [col for col in features_cat_reg if col != "class"]

train_encod = OH_encoder.fit_transform(train_set_bus[cat_cols])
test_encod = OH_encoder.transform(test_set_bus[cat_cols])

# Convertimos a DataFrame con nombres de columna
col_names = OH_encoder.get_feature_names_out(cat_cols)
train_encod_df = pd.DataFrame(train_encod, columns = col_names, index = train_set_bus.index)
test_encod_df = pd.DataFrame(test_encod, columns = col_names, index = test_set_bus.index)
resto_cols = [col for col in features if col not in cat_cols]
resto_cols
train_set_bus = pd.concat([train_set_bus[resto_cols + [target_reg]], train_encod_df], axis = 1)
test_set_bus = pd.concat([test_set_bus[resto_cols + [target_reg]], test_encod_df], axis = 1)

# %% [markdown]
# ----

# %% [markdown]
# **Con pipeline**

# %%
X_train_pipe = train_set_copy.drop(columns= target_reg, axis = 1)
y_train_pipe = train_set_copy[target_reg]

X_test_pipe = test_set_copy.drop(columns= target_reg, axis = 1)
y_test_pipe = test_set_copy[target_reg]

# %%
categorias = [["economy", "business"]]
cat_cols = [col for col in features_cat_reg if col != "class"]

preprocesing = ColumnTransformer([
    ("procesar_cat_ord", OrdinalEncoder(categories = categorias, handle_unknown = "use_encoded_value", unknown_value = -1), ["class"]),
    ("procesar_cat_OH", OneHotEncoder(handle_unknown = "ignore"), cat_cols)
], remainder = "passthrough")

# %%
rf_pipeline = Pipeline([
    ("preprocesado", preprocesing),
    ("modelo", RandomForestRegressor())
])

lgb_pipeline = Pipeline([
    ("preprocesado", preprocesing),
    ("modelo", LGBMRegressor())
])

xgb_pipeline = Pipeline([
    ("preprocesado", preprocesing),
    ("modelo", XGBRegressor())
])

modelos = {
    "rf": rf_pipeline,
    "lgb": lgb_pipeline,
    "xgb": xgb_pipeline
}

# %%
metricas_cv = {}

scoring = {
    "rmse": "neg_root_mean_squared_error",
    "mae": "neg_mean_absolute_error",
    "r2": "r2"
}

for nombre, pipe in modelos.items():
    valores = cross_validate(pipe, X_train_pipe, y_train_pipe, cv = 5, scoring = scoring)
    metricas_cv[nombre] = valores


for model_name, valores in metricas_cv.items():
    rmse = -np.mean(valores["test_rmse"])
    mae = -np.mean(valores["test_mae"])
    r2 = np.mean(valores["test_r2"])

    print(f"Model <{model_name}>:")
    print(f"\t RMSE_CV: {rmse}")
    print(f"\t MAE_CV: {mae}")
    print(f"\t R2-score_CV: {r2}")

# %% [markdown]
# Optimizar con optuna

# %%
# Definir función objetivo para Optuna

def objective(trial):
    param_grid = {
        "modelo__n_estimators": trial.suggest_int("modelo__n_estimators", 100, 800),
        "modelo__max_depth": trial.suggest_int("modelo__max_depth", 5, 15),
        "modelo__num_leaves": trial.suggest_int("modelo__num_leaves", 7, 260),
        "modelo__learning_rate": trial.suggest_float("modelo__learning_rate", 0.05, 1),
        "modelo__min_data_in_leaf": trial.suggest_int("modelo__min_data_in_leaf", 10, 200)
    }

    lgb_pipeline.set_params(**param_grid)

    score = cross_val_score(
        lgb_pipeline,
        X_train,
        y_train,
        cv = 5,
        scoring = "neg_root_mean_squared_error",
        n_jobs = -1
    ).mean()

    return -score

# %%
study_pipe = optuna.create_study(direction="minimize")
study_pipe.optimize(objective, n_trials=50)

# %%
# Crear y ejecutar estudy de Optuna
study_pipe = optuna.create_study(direction = "minimize",
                            sampler = optuna.samplers.TPESampler(seed = 42))

# %%
study_pipe.optimize(objective, n_trials= 200) # optimizar el estudio

# %%
print(study_pipe.best_value)
best_params_pipe = study_pipe.best_params
best_params_pipe

# %%
best_model_pipe = lgb_pipeline.set_params(**best_params_pipe)

best_model_pipe.fit(X_train_pipe, y_train_pipe)

# %%
joblib.dump(best_model_pipe, "lgbm_best_model_pipe.joblib")

# %%
y_pred = best_model_pipe.predict(X_test_pipe)
print("RMSE:", root_mean_squared_error(y_test_pipe, y_pred))
print("MAE:", mean_absolute_error(y_test_pipe, y_pred))
print("R2:", r2_score(y_test_pipe, y_pred))

# %% [markdown]
# ----

# %%
plt.figure(figsize=(12,6))
train_set['airline'].value_counts().plot(kind='bar')
plt.title("Número de vuelos por aerolínea")
plt.xlabel("Aerolínea")
plt.ylabel("Cantidad de vuelos")
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Conteo y porcentaje
counts = train_set["airline"].value_counts()
percent = counts / counts.sum() * 100

plt.figure(figsize=(10, 8))

# Pie chart
plt.pie(
    counts,
    startangle=90,
    colors=sns.color_palette("tab20"),
    wedgeprops={"linewidth": 1, "edgecolor": "white"}
)

# Leyenda con porcentajes (3 decimales)
labels = [f"{airline}: {pct:.3f}%" for airline, pct in zip(counts.index, percent)]
plt.legend(
    labels,
    loc="center left",
    bbox_to_anchor=(1, 0.5),
    fontsize=12,
    title="Aerolíneas"
)

plt.title("Porcentaje total de vuelos por aerolínea", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# Ingresos aproximados por aerolínea

# %%
train_set.groupby('airline')['price'].sum().sort_values(ascending=False)
# Out:
# airline
# Vistara      3.098865e+09
# Air India    1.522199e+09
# Indigo       1.809659e+08
# GO FIRST     1.043377e+08
# Otra         9.638645e+07
# Name: price, dtype: float64

# %% [markdown]
# El dinero esta en rupias

# %%
train_set.groupby('airline')['price'].sum().sort_values().plot(kind='barh', figsize=(10,6))
plt.title("Ingresos aproximados por aerolínea")
plt.xlabel("Ingresos totales")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Agrupar ingresos por aerolínea y clase
income_class = train_set.groupby(['airline', 'class'])['price'].sum().reset_index()

# Calcular porcentaje dentro de cada aerolínea
income_class['percent'] = income_class.groupby('airline')['price'].transform(lambda x: x / x.sum() * 100)

plt.figure(figsize=(12,6))

ax = sns.barplot(
    data=income_class,
    x='airline',
    y='percent',
    hue='class',
    palette='tab10'
)

# Añadir etiquetas de porcentaje encima de cada barra
for container in ax.containers:
    ax.bar_label(container, fmt='%.1f%%', padding=3)

plt.title("Porcentaje de ingresos por aerolínea (Economy vs Business)", fontsize=16)
plt.xlabel("Aerolínea")
plt.ylabel("Porcentaje de ingresos (%)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Porcentaje por aerolinea de vuelos business

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filtrar solo vuelos Business
business_df = train_set[train_set['class'] == 'business']

# Contar vuelos business por aerolínea
business_counts = business_df['airline'].value_counts()

# Calcular porcentaje sobre el total del mercado business
business_percent = business_counts / business_counts.sum() * 100

plt.figure(figsize=(12,6))
ax = sns.barplot(
    x=business_percent.index,
    y=business_percent.values,
    palette="Blues"
)

# Etiquetas encima de cada barra
for container in ax.containers:
    ax.bar_label(container, fmt='%.1f%%', padding=3)

plt.title("Participación de mercado en vuelos Business por aerolínea", fontsize=16)
plt.xlabel("Aerolínea")
plt.ylabel("Porcentaje del mercado Business (%)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lufue\AppData\Local\Temp\ipykernel_17540\4032887624.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %% [markdown]
# Porcentaje por aerolinea de Economy

# %%
# Paleta igual que el pie chart
colors = sns.color_palette("tab20")

# Orden de aerolíneas según el pie chart
counts = train_set["airline"].value_counts()
airline_order = counts.index.tolist()

# Filtrar solo vuelos Economy
economy_df = train_set[train_set['class'] == 'economy']

# Contar vuelos economy por aerolínea
economy_counts = economy_df['airline'].value_counts()

# Calcular porcentaje sobre el total del mercado economy
economy_percent = economy_counts / economy_counts.sum() * 100

# Alinear colores con el orden del pie chart
economy_colors = [colors[airline_order.index(a)] for a in economy_percent.index]

plt.figure(figsize=(12,6))
ax = sns.barplot(
    x=economy_percent.index,
    y=economy_percent.values,
    palette=economy_colors
)

# Etiquetas encima de cada barra
for container in ax.containers:
    ax.bar_label(container, fmt='%.3f%%', padding=3)

plt.title("Participación de mercado en vuelos Economy por aerolínea", fontsize=16)
plt.xlabel("Aerolínea")
plt.ylabel("Porcentaje del mercado Economy (%)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lufue\AppData\Local\Temp\ipykernel_17540\1095963594.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %% [markdown]
# Analizando todo esto

# %% [markdown]
# Air India debe ser tu aerolínea
# Y te explico por qué es la opción más sólida:
#
# 1. Tiene un tamaño grande pero no dominante
# - No es tan gigante como Vistara
# - No es tan pequeña como Indigo
# - Está justo en el medio
#
# 2. Tiene mezcla de clases
# - 35% del mercado Business
# - 23% del mercado Economy
# - Ingresos altos pero no extremos
# - Esto es perfecto para un modelo de ML porque hay variabilidad real.
#
# 3. Tiene rivales claros
# - Premium: Vistara
# - Low‑cost: Indigo, GO FIRST, AirAsia, SpiceJet
# - Tu modelo podrá aprender patrones de ambos mundos.
#
# 4. Es la aerolínea más equilibrada del dataset
# - Ni demasiado premium
# - Ni demasiado low‑cost
# - Ni demasiado pequeña
# - Ni demasiado dominante
#
# Es la aerolínea “intermedia” ideal para un proyecto académico.

# %% [markdown]
# ¿Por qué NO incluir StarAir y TruJet?
# Tus gráficos muestran:
#
# StarAir:
# - 0.02% de los vuelos
# - ingresos insignificantes
# - casi sin datos
# - comportamiento no representativo
# - demasiado ruido para un modelo de ML
#
# TruJet:
# - 0.014% de los vuelos
# - aún menos datos
# - no aporta señal
# - puede distorsionar el modelo
#
# Son outliers del mercado, no competidores reales de Air India

# %% [markdown]
# Qué aerolíneas SÍ incluir?
#
# Estas son las que realmente compiten en el mercado:
#
# Vistara:
# - Rival premium
# - Mucho volumen
# - Precios altos
# - Perfecta para estudiar
#
# GO FIRST:
# - Low‑cost
# - Competidor directo en rutas económicas
#
# AirAsia
# - Low‑cost
# - Patrón de precios interesante
#
# SpiceJet
# - Low‑cost
# - Competidor real en rutas domésticas

# %%
df_ml.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 217225 entries, 0 to 298208
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           217225 non-null  str
#  1   source_city       217225 non-null  str
#  2   destination_city  217225 non-null  str
#  3   price             217225 non-null  float64
#  4   duration          217225 non-null  float64
#  5   dep_time_cat      217225 non-null  str
#  6   arr_time_cat      217225 non-null  str
#  7   days_left         217225 non-null  int64
#  8   class             217225 non-null  str
#  9   stop_num          217225 non-null  int64
# dtypes: float64(2), int64(2), str(6)
# memory usage: 18.2 MB

# %%
df_ml.describe()
# Out:
#                price       duration      days_left       stop_num
# count  217225.000000  217225.000000  217225.000000  217225.000000
# mean    20024.419883      11.077931      25.193546       0.916115
# std     23304.681420       6.617793      13.488459       0.408854
# min      1105.000000       0.833333       0.000000       0.000000
# 25%      4502.000000       6.333333      14.000000       1.000000
# 50%      6728.000000      10.083333      25.000000       1.000000
# 75%     38099.000000      14.500000      37.000000       1.000000
# max    123071.000000      47.083333      48.000000       2.000000

# %% [markdown]
# Matriz de correlacion

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Seleccionar solo columnas numéricas
num_cols = ['price', 'duration', 'days_left', 'stop_num']

corr_matrix = df_ml[num_cols].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Matriz de correlación (variables numéricas)")
plt.show()

# %% [markdown]
# Histograma de la variable target

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df_ml['price'], bins=50, kde=True, color='royalblue')
plt.title("Distribución de la variable target: price")
plt.xlabel("Precio del vuelo")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# **Machine_Learning**

# %%
features_num = ['duration', 'days_left', 'stop_num']

features_cat = [
    'airline',
    'source_city',
    'destination_city',
    'dep_time_cat',
    'arr_time_cat',
    'class'
]

# %%
from sklearn.model_selection import train_test_split

X = df_ml[features_num + features_cat]
y = df_ml['price']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)

# %%
'''from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), features_cat),
        ('num', StandardScaler(), features_num)
    ]
)'''

# %% [markdown]
# PIPELINE 1 — Modelos lineales (OneHot + StandardScaler)

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

preprocessor_linear = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), features_cat),
        ('num', StandardScaler(), features_num)
    ]
)

# %% [markdown]
# PIPELINE 2 — Modelos de árboles (OneHot + numéricas sin tocar)

# %%
'''preprocessor_trees = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), features_cat),
        ('num', 'passthrough', features_num)
    ]
)'''

# %%
from sklearn.preprocessing import OrdinalEncoder

preprocessor_trees = ColumnTransformer(
    transformers=[
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), features_cat),
        ('num', 'passthrough', features_num)
    ]
)

# %% [markdown]
# PIPELINE 3 — CatBoost (sin preprocesamiento)

# %%
from catboost import CatBoostRegressor

model_cat = CatBoostRegressor(
    depth=8,
    learning_rate=0.05,
    iterations=600,
    loss_function="RMSE",
    verbose=0,
    random_state=42
)

# %%
from sklearn.metrics import make_scorer, mean_absolute_error, r2_score

mae_scorer = make_scorer(mean_absolute_error, greater_is_better=False)
r2_scorer = make_scorer(r2_score)

# %% [markdown]
# BLOQUE 1 — Modelos lineales

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
import numpy as np

models_linear = {
    "LinearRegression": LinearRegression(),
    "Ridge": Ridge(),
    "Lasso": Lasso()
}

results_linear = {}

for name, reg in models_linear.items():
    pipe = Pipeline([
        ('preprocessor', preprocessor_linear),
        ('regressor', reg)
    ])
    
    rmse = -cross_val_score(pipe, X_train, y_train,
                            scoring='neg_root_mean_squared_error',
                            cv=5, n_jobs=-1).mean()
    
    mae  = -cross_val_score(pipe, X_train, y_train,
                            scoring=mae_scorer,
                            cv=5, n_jobs=-1).mean()
    
    r2   =  cross_val_score(pipe, X_train, y_train,
                            scoring=r2_scorer,
                            cv=5, n_jobs=-1).mean()

    results_linear[name] = {"RMSE": rmse, "MAE": mae, "R2": r2}

    print(f"\n📌 {name}")
    print(f"   RMSE CV: {rmse:.2f}")
    print(f"   MAE  CV: {mae:.2f}")
    print(f"   R²   CV: {r2:.4f}")
# Out:
# 📌 LinearRegression
#    RMSE CV: 6704.70
#    MAE  CV: 4256.78
#    R²   CV: 0.9171
#
# 📌 Ridge
#    RMSE CV: 6704.70
#    MAE  CV: 4256.65
#    R²   CV: 0.9171
#
# 📌 Lasso
#    RMSE CV: 6704.72
#    MAE  CV: 4254.87
#    R²   CV: 0.9171

# %% [markdown]
# BLOQUE 2 — Modelos de árboles

# %%
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

models_trees = {
    "RandomForest": RandomForestRegressor(
        n_estimators=300, random_state=42, n_jobs=-1
    ),
    "XGBoost": XGBRegressor(
        n_estimators=400, learning_rate=0.05, max_depth=6,
        subsample=0.8, colsample_bytree=0.8,
        objective="reg:squarederror", random_state=42, n_jobs=-1
    ),
    "LightGBM": LGBMRegressor(
        n_estimators=400, learning_rate=0.05,
        subsample=0.8, colsample_bytree=0.8,
        random_state=42, n_jobs=-1
    )
}

results_trees = {}

for name, reg in models_trees.items():
    pipe = Pipeline([
        ('preprocessor', preprocessor_trees),
        ('regressor', reg)
    ])
    
    rmse = -cross_val_score(pipe, X_train, y_train,
                            scoring='neg_root_mean_squared_error',
                            cv=5, n_jobs=-1).mean()
    
    mae  = -cross_val_score(pipe, X_train, y_train,
                            scoring=mae_scorer,
                            cv=5, n_jobs=-1).mean()
    
    r2   =  cross_val_score(pipe, X_train, y_train,
                            scoring=r2_scorer,
                            cv=5, n_jobs=-1).mean()

    results_trees[name] = {"RMSE": rmse, "MAE": mae, "R2": r2}

    print(f"\n📌 {name}")
    print(f"   RMSE CV: {rmse:.2f}")
    print(f"   MAE  CV: {mae:.2f}")
    print(f"   R²   CV: {r2:.4f}")
# Out:
# 📌 RandomForest
#    RMSE CV: 3028.55
#    MAE  CV: 1247.54
#    R²   CV: 0.9831
#
# 📌 XGBoost
#    RMSE CV: 3737.24
#    MAE  CV: 2118.54
#    R²   CV: 0.9742
#
# 📌 LightGBM
#    RMSE CV: 3633.81
#    MAE  CV: 2112.41
#    R²   CV: 0.9756

# %% [markdown]
# BLOQUE 3 — CatBoost (sin preprocesador)

# %%
results_cat = {}

rmse = -cross_val_score(model_cat, X_train, y_train,
                        scoring='neg_root_mean_squared_error',
                        cv=5, n_jobs=-1).mean()

mae  = -cross_val_score(model_cat, X_train, y_train,
                        scoring=mae_scorer,
                        cv=5, n_jobs=-1).mean()

r2   =  cross_val_score(model_cat, X_train, y_train,
                        scoring=r2_scorer,
                        cv=5, n_jobs=-1).mean()

results_cat["CatBoost"] = {"RMSE": rmse, "MAE": mae, "R2": r2}

print(f"\n📌 CatBoost")
print(f"   RMSE CV: {rmse:.2f}")
print(f"   MAE  CV: {mae:.2f}")
print(f"   R²   CV: {r2:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 3
#       1 results_cat = {}
# ----> 3 rmse = -cross_val_score(model_cat, X_train, y_train,
#       4                         scoring='neg_root_mean_squared_error',
#       5                         cv=5, n_jobs=-1).mean()
#       7 mae  = -cross_val_score(model_cat, X_train, y_train,
#       8                         scoring=mae_scorer,
#       9                         cv=5, n_jobs=-1).mean()
#      11 r2   =  cross_val_score(model_cat, X_train, y_train,
#      12                         scoring=r2_scorer,
#      13                         cv=5, n_jobs=-1).mean()
#
# File c:\Users\César\OneDrive\Escritorio\DS\ML_Prediccion_Precios_Vuelos\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\César\OneDrive\Escritorio\DS\ML_Prediccion_Precios_Vuelos\.venv\Lib\site-packages\sklearn\model_selection\_validation.py:651, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, error_score)
#     648 # To ensure multimetric format is not supported
#     649 scorer = check_scoring(estimator, scoring=scoring)
# --> 651 cv_results = cross_validate(
#     652     estimator=estimator,
#     653     X=X,
#     654     y=y,
#     655     groups=groups,
#     656     scoring={"score": scorer},
#     657     cv=cv,
#     658     n_jobs=n_jobs,
#     659     verbose=verbose,
#     660     params=params,
#     661     pre_dispatch=pre_dispatch,
#     662     error_score=error_score,
#     663 )
#     664 return cv_results["test_score"]
#
# File c:\Users\César\OneDrive\Escritorio\DS\ML_Prediccion_Precios_Vuelos\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\César\OneDrive\Escritorio\DS\ML_Prediccion_Precios_Vuelos\.venv\Lib\site-packages\sklearn\model_selection\_validation.py:393, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     372 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
#     373 results = parallel(
#     374     delayed(_fit_and_score)(
#     375         clone(estimator),
#    (...)    390     for train, test in indices
#     391 )
# --> 393 _warn_or_raise_about_fit_failures(results, error_score)
#     395 # For callable scoring, the return type is only know after calling. If the
#     396 # return type is a dictionary, the error scores can now be inserted with
#     397 # the correct key.
#     398 if callable(scoring):
#
# File c:\Users\César\OneDrive\Escritorio\DS\ML_Prediccion_Precios_Vuelos\.venv\Lib\site-packages\sklearn\model_selection\_validation.py:479, in _warn_or_raise_about_fit_failures(results, error_score)
#     472 if num_failed_fits == num_fits:
#     473     all_fits_failed_message = (
#     474         f"\nAll the {num_fits} fits failed.\n"
#     475         "It is very likely that your model is misconfigured.\n"
#     476         "You can try to debug the error by setting error_score='raise'.\n\n"
#     477         f"Below are more details about the failures:\n{fit_errors_summary}"
#     478     )
# --> 479     raise ValueError(all_fits_failed_message)
#     481 else:
#     482     some_fits_failed_message = (
#     483         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     484         "The score on these train-test partitions for these parameters"
#    (...)    488         f"Below are more details about the failures:\n{fit_errors_summary}"
#     489     )
#
# ValueError:
# All the 5 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "_catboost.pyx", line 2606, in _catboost.get_float_feature
#   File "_catboost.pyx", line 1290, in _catboost._FloatOrNan
#   File "_catboost.pyx", line 1039, in _catboost._FloatOrNanFromString
# TypeError: Cannot convert 'Vistara' to float
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\César\OneDrive\Escritorio\DS\ML_Prediccion_Precios_Vuelos\.venv\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\César\OneDrive\Escritorio\DS\ML_Prediccion_Precios_Vuelos\.venv\Lib\site-packages\catboost\core.py", line 6178, in fit
#     return self._fit(X, y, cat_features, text_features, embedding_features, None, graph, sample_weight, None, None, None, None, baseline,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\César\OneDrive\Escritorio\DS\ML_Prediccion_Precios_Vuelos\.venv\Lib\site-packages\catboost\core.py", line 2701, in _fit
#     train_params = self._prepare_train_params(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\César\OneDrive\Escritorio\DS\ML_Prediccion_Precios_Vuelos\.venv\Lib\site-packages\catboost\core.py", line 2581, in _prepare_train_params
#     train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs, graph,
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\César\OneDrive\Escritorio\DS\ML_Prediccion_Precios_Vuelos\.venv\Lib\site-packages\catboost\core.py", line 1540, in _build_train_pool
#     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, graph=graph, weight=sample_weight, group_id=group_id,
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\César\OneDrive\Escritorio\DS\ML_Prediccion_Precios_Vuelos\.venv\Lib\site-packages\catboost\core.py", line 863, in __init__
#     self._init(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, graph, weight,
#   File "c:\Users\César\OneDrive\Escritorio\DS\ML_Prediccion_Precios_Vuelos\.venv\Lib\site-packages\catboost\core.py", line 1518, in _init
#     self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, graph, weight,
#   File "_catboost.pyx", line 4695, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 4753, in _catboost._PoolBase._init_pool
#   File "_catboost.pyx", line 4541, in _catboost._PoolBase._init_features_order_layout_pool
#   File "_catboost.pyx", line 3189, in _catboost._set_features_order_data_pd_data_frame
#   File "_catboost.pyx", line 2673, in _catboost.create_num_factor_data
#   File "_catboost.pyx", line 2635, in _catboost._set_features_order_data_frame_generic_num_column
#   File "_catboost.pyx", line 2608, in _catboost.get_float_feature
# _catboost.CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=3]="Vistara": Cannot convert 'Vistara' to float

# %% [markdown]
# BLOQUE 1 — Modelos lineales

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error, r2_score
import numpy as np

mae_scorer = make_scorer(mean_absolute_error, greater_is_better=False)
r2_scorer = make_scorer(r2_score)

models_linear = {
    "LinearRegression": LinearRegression(),
    "Ridge": Ridge(),
    "Lasso": Lasso()
}

results_linear = {}

for name, reg in models_linear.items():
    pipe = Pipeline([
        ('preprocessor', preprocessor_linear),
        ('regressor', reg)
    ])
    
    rmse = -cross_val_score(pipe, X_train, y_train,
                            scoring='neg_root_mean_squared_error',
                            cv=5, n_jobs=-1).mean()
    
    mae  = -cross_val_score(pipe, X_train, y_train,
                            scoring=mae_scorer,
                            cv=5, n_jobs=-1).mean()
    
    r2   =  cross_val_score(pipe, X_train, y_train,
                            scoring=r2_scorer,
                            cv=5, n_jobs=-1).mean()

    results_linear[name] = {"RMSE": rmse, "MAE": mae, "R2": r2}

    print(f"\n📌 {name}")
    print(f"   RMSE CV: {rmse:.2f}")
    print(f"   MAE  CV: {mae:.2f}")
    print(f"   R²   CV: {r2:.4f}")
# Out:
# 📌 LinearRegression
#    RMSE CV: 6704.70
#    MAE  CV: 4256.78
#    R²   CV: 0.9171
#
# 📌 Ridge
#    RMSE CV: 6704.70
#    MAE  CV: 4256.65
#    R²   CV: 0.9171
#
# 📌 Lasso
#    RMSE CV: 6704.72
#    MAE  CV: 4254.87
#    R²   CV: 0.9171

# %% [markdown]
# BLOQUE 2 — Modelos de árboles

# %%
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

models_trees = {
    "RandomForest": RandomForestRegressor(n_estimators=300, random_state=42),
    "XGBoost": XGBRegressor(
        n_estimators=400, learning_rate=0.05, max_depth=6,
        subsample=0.8, colsample_bytree=0.8,
        objective="reg:squarederror", random_state=42
    ),
    "LightGBM": LGBMRegressor(
        n_estimators=400, learning_rate=0.05,
        subsample=0.8, colsample_bytree=0.8,
        random_state=42
    )
}

results_trees = {}

for name, reg in models_trees.items():
    pipe = Pipeline([
        ('preprocessor', preprocessor_trees),
        ('regressor', reg)
    ])
    
    rmse = -cross_val_score(pipe, X_train, y_train,
                            scoring='neg_root_mean_squared_error',
                            cv=5, n_jobs=-1).mean()
    
    mae  = -cross_val_score(pipe, X_train, y_train,
                            scoring=mae_scorer,
                            cv=5, n_jobs=-1).mean()
    
    r2   =  cross_val_score(pipe, X_train, y_train,
                            scoring=r2_scorer,
                            cv=5, n_jobs=-1).mean()

    results_trees[name] = {"RMSE": rmse, "MAE": mae, "R2": r2}

    print(f"\n📌 {name}")
    print(f"   RMSE CV: {rmse:.2f}")
    print(f"   MAE  CV: {mae:.2f}")
    print(f"   R²   CV: {r2:.4f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[92], line 27
#      21 for name, reg in models_trees.items():
#      22     pipe = Pipeline([
#      23         ('preprocessor', preprocessor_trees),
#      24         ('regressor', reg)
#      25     ])
# ---> 27     rmse = -cross_val_score(pipe, X_train, y_train,
#      28                             scoring='neg_root_mean_squared_error',
#      29                             cv=5, n_jobs=-1).mean()
#      31     mae  = -cross_val_score(pipe, X_train, y_train,
#      32                             scoring=mae_scorer,
#      33                             cv=5, n_jobs=-1).mean()
#      35     r2   =  cross_val_score(pipe, X_train, y_train,
#      36                             scoring=r2_scorer,
#      37                             cv=5, n_jobs=-1).mean()
#
# File c:\Users\César\OneDrive\Escritorio\DS\ML_Prediccion_Precios_Vuelos\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\César\OneDrive\Escritorio\DS\ML_Prediccion_Precios_Vuelos\.venv\Lib\site-packages\sklearn\model_selection\_validation.py:651, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, error_score)
#     648 # To ensure multimetric format is not supported
#     649 scorer = check_scoring(estimator, scoring=scoring)
# --> 651 cv_results = cross_validate(
#     652     estimator=estimator,
#     653     X=X,
#     654     y=y,
#     655     groups=groups,
#     656     scoring={"score": scorer},
#     657     cv=cv,
#     658     n_jobs=n_jobs,
#     659     verbose=verbose,
#     660     params=params,
#     661     pre_dispatch=pre_dispatch,
#     662     error_score=error_score,
#     663 )
#     664 return cv_results["test_score"]
#
# File c:\Users\César\OneDrive\Escritorio\DS\ML_Prediccion_Precios_Vuelos\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\César\OneDrive\Escritorio\DS\ML_Prediccion_Precios_Vuelos\.venv\Lib\site-packages\sklearn\model_selection\_validation.py:373, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     370 # We clone the estimator to make sure that all the folds are
#     371 # independent, and that it is pickle-able.
#     372 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 373 results = parallel(
#     374     delayed(_fit_and_score)(
#     375         clone(estimator),
#     376         X,
#     377         y,
#     378         scorer=scorers,
#     379         train=train,
#     380         test=test,
#     381         verbose=verbose,
#     382         parameters=None,
#     383         fit_params=routed_params.estimator.fit,
#     384         score_params=routed_params.scorer.score,
#     385         return_train_score=return_train_score,
#     386         return_times=True,
#     387         return_estimator=return_estimator,
#     388         error_score=error_score,
#     389     )
#     390     for train, test in indices
#     391 )
#     393 _warn_or_raise_about_fit_failures(results, error_score)
#     395 # For callable scoring, the return type is only know after calling. If the
#     396 # return type is a dictionary, the error scores can now be inserted with
#     397 # the correct key.
#
# File c:\Users\César\OneDrive\Escritorio\DS\ML_Prediccion_Precios_Vuelos\.venv\Lib\site-packages\sklearn\utils\parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File c:\Users\César\OneDrive\Escritorio\DS\ML_Prediccion_Precios_Vuelos\.venv\Lib\site-packages\joblib\parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File c:\Users\César\OneDrive\Escritorio\DS\ML_Prediccion_Precios_Vuelos\.venv\Lib\site-packages\joblib\parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File c:\Users\César\OneDrive\Escritorio\DS\ML_Prediccion_Precios_Vuelos\.venv\Lib\site-packages\joblib\parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)   1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %% [markdown]
# BLOQUE 3 — CatBoost (sin preprocesador)

# %%
results_cat = {}

rmse = -cross_val_score(model_cat, X_train, y_train,
                        scoring='neg_root_mean_squared_error',
                        cv=5, n_jobs=-1).mean()

mae  = -cross_val_score(model_cat, X_train, y_train,
                        scoring=mae_scorer,
                        cv=5, n_jobs=-1).mean()

r2   =  cross_val_score(model_cat, X_train, y_train,
                        scoring=r2_scorer,
                        cv=5, n_jobs=-1).mean()

results_cat["CatBoost"] = {"RMSE": rmse, "MAE": mae, "R2": r2}

print(f"\n📌 CatBoost")
print(f"   RMSE CV: {rmse:.2f}")
print(f"   MAE  CV: {mae:.2f}")
print(f"   R²   CV: {r2:.4f}")

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor

models = {
    "LinearRegression": LinearRegression(),
    "Ridge": Ridge(),
    "Lasso": Lasso(),
    "SVR": SVR(),
    "RandomForest": RandomForestRegressor(n_estimators=300, random_state=42),

    "XGBoost": XGBRegressor(
        n_estimators=400,
        learning_rate=0.05,
        max_depth=6,
        subsample=0.8,
        colsample_bytree=0.8,
        objective="reg:squarederror",
        random_state=42
    ),

    "LightGBM": LGBMRegressor(
        n_estimators=400,
        learning_rate=0.05,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=42
    ),

    "CatBoost": CatBoostRegressor(
        depth=8,
        learning_rate=0.05,
        iterations=600,
        loss_function="RMSE",
        verbose=0,
        random_state=42
    )
}

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error, r2_score
import numpy as np

mae_scorer = make_scorer(mean_absolute_error, greater_is_better=False)
r2_scorer = make_scorer(r2_score)

results = {}

for name, reg in models.items():
    pipe = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('regressor', reg)
    ])
    
    # RMSE
    rmse_scores = cross_val_score(
        pipe, X_train, y_train,
        scoring='neg_root_mean_squared_error',
        cv=5
    )
    
    # MAE
    mae_scores = cross_val_score(
        pipe, X_train, y_train,
        scoring=mae_scorer,
        cv=5
    )
    
    # R²
    r2_scores = cross_val_score(
        pipe, X_train, y_train,
        scoring=r2_scorer,
        cv=5
    )
    
    results[name] = {
        "RMSE_CV": -rmse_scores.mean(),
        "MAE_CV": -mae_scores.mean(),
        "R2_CV": r2_scores.mean()
    }
    
    print(f"\n📌 Modelo: {name}")
    print(f"   RMSE CV: {-rmse_scores.mean():.2f}")
    print(f"   MAE  CV: {-mae_scores.mean():.2f}")
    print(f"   R²   CV: {r2_scores.mean():.4f}")
# Out:
# 📌 Modelo: LinearRegression
#    RMSE CV: 6704.70
#    MAE  CV: 4256.78
#    R²   CV: 0.9171
#
# 📌 Modelo: Ridge
#    RMSE CV: 6704.70
#    MAE  CV: 4256.65
#    R²   CV: 0.9171
#
# 📌 Modelo: Lasso
#    RMSE CV: 6704.72
#    MAE  CV: 4254.87
#    R²   CV: 0.9171

# %%
dup_economy = df_economy[df_economy.duplicated(subset=cols, keep=False)]
dup_business = df_business[df_business.duplicated(subset=cols, keep=False)]

len(dup_economy), len(dup_business)
# Out:
# (70, 0)

# %%
df_concat = pd.concat([df_economy, df_business], ignore_index=True)

df_concat_clean = df_concat.drop_duplicates(subset=cols)

df_concat.shape[0] - df_concat_clean.shape[0]
# Out:
# 35
